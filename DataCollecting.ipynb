# %% [markdown]
# # Introduction to Data Science

# %% [markdown]
# ### Project topic: Weather forecasting in Toronto City

# %% [markdown]
# ### Description
# - _This is a project to apply our knowlegde in Data Science to solve the weather forecasting problem in Toronto City._
#
# - _The dataset that we have collected is from the Canada government's website: [climate](https://climate.weather.gc.ca/historical_data/search_historic_data_e.html)_
#
# - _In this case, we are going to use Python frameworks like: `requests`, `BeautifulSoup` to automatically collect the data._
#
# - _Based on the collected dataset, we will apply some DS techniques in order to forecast the weather in Toronto City hourly._

# %% [markdown]
# ### Group - 07:
# - **21127072 - Nguyễn Hữu Khánh**
# - 21127160 - Nguyễn Thanh Sơn
# - 21127246 - Lê Minh Đức

# %% [markdown]
# ### Prepare

# %% [markdown]
# - Install libraries

# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install lxml

# %% [markdown]
# - Import libraries

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import selenium as se
import math

from datetime import datetime
from bs4 import BeautifulSoup
from io import StringIO

# %% [markdown]
# - Declare important variables

# %%
# Data URL
url = 'https://climate.weather.gc.ca/climate_data/hourly_data_e.html'

# DataFrame to store data
datas = pd.DataFrame()

# %% [markdown]
# ### Support Function

# %%
def is_valid_date(year, month, day):
    try:
        datetime(year, month, day)
        return True
    except ValueError:
        return False
    
def fixDataFramTimeUTC(df, year, month, day):
    nump = np.asarray(df['TIME UTC'])
    nump = datetime(year,month,day).strftime("%Y-%m-%d") + "T" + nump
    df['TIME UTC'] = nump

# %% [markdown]
# ### Get data

# %%
def getDataFromWeb(m_start, y_start, m_end, y_end, url_data):
    result = None
    for year in range(y_start, y_end + 1):
        for month in range(1, 13):
            for day in range(1, 32):
                if not is_valid_date(year, month, day) \
                    or ((year == y_start and month < m_start) or (year == y_end and month > m_end)):
                    continue 
                print(f'{year}-{month}-{day}')   
                params = {'StationID': '31688', 'selRowPerPage': 25, 'timeframe': 1, 'time': 'UTC', 'Year': year, 'Month': month, 'Day': day}
                response = requests.get(url_data, params=params)
                soup = BeautifulSoup(response.text,'html.parser')
                daily_table = soup.find('table')
                df = pd.read_html(StringIO(str(daily_table)))[0]
                fixDataFramTimeUTC(df, year, month, day)
                result = pd.concat([result, df], ignore_index=True)
    return result

# %%
datas = getDataFromWeb(1,2020,2,2020,url)

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# #### Remove unnecessary or unpredictable columns

# %%
datas = datas[["TIME UTC",
               "Temp Definition °C",
               "Dew Point Definition °C", 
               "Rel Hum Definition %", 
               "Precip. Amount Definition mm", 
               "Stn Press Definition kPa", 
               "Hmdx Definition", 
               "Weather Definition"]]

# %% [markdown]
# #### Handle missing value

# %% [markdown]
# ##### Fill in missing data rows

# %% [markdown]
# ##### Fill in the humidex index columns

# %% [markdown]
# - Convert `datas` to _list_

# %%
data_list = datas.values.tolist()

# %% [markdown]
# - Setup humidex calculate function
#
# $$H = T_{air} + \frac{5}{9} (6.11 * exp(5417.7530(\frac{1}{273.15} - \frac{1}{273.15 + T_{dew}})) - 10)$$
#
#   - **Where:**
#     - **$H$:** denotes the Humidex
#     - **$T_{air}$:** is the air temperature in °C
#     - **$T_{dew}$:** is the dewpoint temperature in °C
#     - **$exp$:** is the exponential function
#
#   - _Reference: [Wikipedia](https://en.wikipedia.org/wiki/Humidex)_

# %%
def hmdx_cal(temp, dew):
    try:
        temp = float(temp)
        dew = float(dew)
    except(ValueError, TypeError):
        return -1
    
    result = temp + (5/9) * (6.11 * math.exp(5417.7530 * ((1 / 273.15)-(1 / (273.15 + dew))))-10)

    return max(result, 0) # Because if humidex < 0, then it is not necessary

# %% [markdown]
# - Use `hmdx_cal` to calculate humidex

# %%
for item in data_list:
    item[6] = round(hmdx_cal(item[1], item[2]),0)
# Out:
# [['2020-01-01T00:00', 0.7, -4.5, 68.0, 0.0, 98.7, 0, 'LegendNANA'],
#  ['2020-01-01T01:00', 0.4, -4.6, 69.0, 0.0, 98.73, 0, 'LegendNANA'],
#  ['2020-01-01T02:00', 0.2, -4.9, 68.0, 0.0, 98.75, 0, 'LegendNANA'],
#  ['2020-01-01T03:00', -0.1, -5.0, 69.0, 0.0, 98.77, 0, 'LegendNANA'],
#  ['2020-01-01T04:00', -0.2, -4.6, 72.0, 0.0, 98.81, 0, 'LegendNANA'],
#  ['2020-01-01T05:00', -0.1, -5.2, 69.0, 0.0, 98.82, 0, 'LegendNANA'],
#  ['2020-01-01T06:00', -0.1, -4.9, 70.0, 0.0, 98.84, 0, 'LegendNANA'],
#  ['2020-01-01T07:00', -0.1, -5.5, 67.0, 0.0, 98.87, 0, 'LegendNANA'],
#  ['2020-01-01T08:00', -0.4, -5.3, 69.0, 0.0, 98.91, 0, 'LegendNANA'],
#  ['2020-01-01T09:00', -0.7, -4.5, 75.0, 0.0, 98.96, 0, 'LegendNANA'],
#  ['2020-01-01T10:00', -0.5, -4.9, 72.0, 0.2, 98.96, 0, 'LegendNANA'],
#  ['2020-01-01T11:00', -0.6, -4.8, 73.0, 0.0, 98.99, 0, 'LegendNANA'],
#  ['2020-01-01T12:00', -0.5, -4.8, 72.0, 0.0, 99.05, 0, 'LegendNANA'],
#  ['2020-01-01T13:00', -0.4, -5.6, 68.0, 0.0, 99.11, 0, 'LegendNANA'],
#  ['2020-01-01T14:00', -0.3, -5.3, 69.0, 0.0, 99.18, 0, 'LegendNANA'],
#  ['2020-01-01T15:00', 0.2, -4.5, 71.0, 0.0, 99.26, 0, 'LegendNANA'],
#  ['2020-01-01T16:00', 0.0, -5.0, 69.0, 0.0, 99.31, 0, 'LegendNANA'],
#  ['2020-01-01T17:00', 0.6, -5.5, 63.0, 0.0, 99.27, 0, 'LegendNANA'],
#  ['2020-01-01T18:00', 0.0, -5.8, 65.0, 0.0, 99.26, 0, 'LegendNANA'],
#  ['2020-01-01T19:00', 0.0, -6.8, 60.0, 0.0, 99.26, 0, 'LegendNANA'],
#  ['2020-01-01T20:00', -0.1, -8.0, 56.0, 0.0, 99.31, 0, 'LegendNANA'],
#  ['2020-01-01T21:00', -0.4, -7.5, 59.0, 0.0, 99.34, 0, 'LegendNANA'],
#  ['2020-01-01T22:00', -0.5, -7.8, 58.0, 0.0, 99.45, 0, 'LegendNANA'],
#  ['2020-01-01T23:00', -0.9, -8.1, 58.0, 0.0, 99.46, 0, 'LegendNANA'],
#  ['2020-01-02T00:00', -0.8, -6.9, 63.0, 0.0, 99.44, 0, 'LegendNANA'],
#  ['2020-01-02T01:00', -1.0, -6.4, 67.0, 0.0, 99.44, 0, 'LegendNANA'],
#  ['2020-01-02T02:00', -0.5, -5.3, 70.0, 0.0, 99.41, 0, 'LegendNANA'],
#  ['2020-01-02T03:00', -0.5, -4.6, 73.0, 0.0, 99.37, 0, 'LegendNANA'],
#  ['2020-01-02T04:00', 0.0, -3.2, 79.0, 0.0, 99.36, 0, 'LegendNANA'],
#  ['2020-01-02T05:00', 0.4, -2.6, 80.0, 0.0, 99.3, 0, 'LegendNANA'],
#  ['2020-01-02T06:00', 0.9, -2.4, 78.0, 0.0, 99.26, 0, 'LegendNANA'],
#  ['2020-01-02T07:00', 2.2, -1.8, 75.0, 0.0, 99.18, 0, 'LegendNANA'],
#  ['2020-01-02T08:00', 2.7, -1.6, 73.0, 0.0, 99.23, 0.0, 'LegendNANA'],
#  ['2020-01-02T09:00', 3.0, -1.0, 75.0, 0.0, 99.19, 1.0, 'LegendNANA'],
#  ['2020-01-02T10:00', 3.4, -1.1, 73.0, 0.0, 99.2, 1.0, 'LegendNANA'],
#  ['2020-01-02T11:00', 3.5, -0.6, 75.0, 0.0, 99.15, 1.0, 'LegendNANA'],
#  ['2020-01-02T12:00', 3.6, -0.8, 73.0, 0.0, 99.19, 1.0, 'LegendNANA'],
#  ['2020-01-02T13:00', 3.8, -0.9, 71.0, 0.0, 99.16, 1.0, 'LegendNANA'],
#  ['2020-01-02T14:00', 4.0, -1.2, 69.0, 0.0, 99.18, 2.0, 'LegendNANA'],
#  ['2020-01-02T15:00', 5.1, -1.9, 61.0, 0.0, 99.17, 2.0, 'LegendNANA'],
#  ['2020-01-02T16:00', 4.9, -1.9, 61.0, 0.0, 99.16, 2.0, 'LegendNANA'],
#  ['2020-01-02T17:00', 5.3, -1.4, 62.0, 0.0, 99.08, 3.0, 'LegendNANA'],
#  ['2020-01-02T18:00', 5.5, -1.7, 59.0, 0.0, 99.02, 3.0, 'LegendNANA'],
#  ['2020-01-02T19:00', 5.7, -1.2, 61.0, 0.0, 98.93, 3.0, 'LegendNANA'],
#  ['2020-01-02T20:00', 5.8, -1.8, 58.0, 0.0, 98.95, 3.0, 'LegendNANA'],
#  ['2020-01-02T21:00', 5.8, -1.9, 58.0, 0.0, 98.96, 3.0, 'LegendNANA'],
#  ['2020-01-02T22:00', 6.0, -1.1, 60.0, 0.0, 99.01, 4.0, 'LegendNANA'],
#  ['2020-01-02T23:00', 5.9, -0.5, 63.0, 0.0, 99.01, 4.0, 'LegendNANA'],
#  ['2020-01-03T00:00', 5.7, -0.1, 67.0, 0.0, 99.13, 4.0, 'LegendNANA'],
#  ['2020-01-03T01:00', 5.6, 0.3, 69.0, 0.0, 99.1, 4.0, 'LegendNANA'],
#  ['2020-01-03T02:00', 5.7, 0.8, 71.0, 0.0, 99.07, 4.0, 'LegendNANA'],
#  ['2020-01-03T03:00', 5.8, 0.6, 69.0, 0.0, 99.07, 4.0, 'LegendNANA'],
#  ['2020-01-03T04:00', 5.2, 0.7, 73.0, 0.0, 99.06, 3.0, 'LegendNANA'],
#  ['2020-01-03T05:00', 5.3, 0.8, 73.0, 0.0, 99.05, 3.0, 'LegendNANA'],
#  ['2020-01-03T06:00', 6.2, 1.3, 71.0, 0.0, 99.1, 4.0, 'LegendNANA'],
#  ['2020-01-03T07:00', 6.9, 1.7, 70.0, 0.0, 99.18, 5.0, 'LegendNANA'],
#  ['2020-01-03T08:00', 6.8, 2.0, 71.0, 0.0, 99.11, 5.0, 'LegendNANA'],
#  ['2020-01-03T09:00', 6.0, 1.8, 75.0, 0.0, 99.13, 4.0, 'LegendNANA'],
#  ['2020-01-03T10:00', 5.9, 2.2, 77.0, 0.0, 99.1, 4.0, 'LegendNANA'],
#  ['2020-01-03T11:00', 6.3, 2.7, 78.0, 0.0, 99.15, 5.0, 'LegendNANA'],
#  ['2020-01-03T12:00', 6.5, 2.8, 77.0, 0.0, 99.17, 5.0, 'LegendNANA'],
#  ['2020-01-03T13:00', 6.4, 2.6, 77.0, 0.0, 99.23, 5.0, 'LegendNANA'],
#  ['2020-01-03T14:00', 6.6, 2.8, 77.0, 0.0, 99.32, 5.0, 'LegendNANA'],
#  ['2020-01-03T15:00', 7.3, 2.8, 73.0, 0.0, 99.37, 6.0, 'LegendNANA'],
#  ['2020-01-03T16:00', 7.6, 2.4, 70.0, 0.0, 99.39, 6.0, 'LegendNANA'],
#  ['2020-01-03T17:00', 7.5, 2.0, 68.0, 0.0, 99.32, 6.0, 'LegendNANA'],
#  ['2020-01-03T18:00', 7.4, 1.7, 67.0, 0.0, 99.28, 6.0, 'LegendNANA'],
#  ['2020-01-03T19:00', 7.2, 1.0, 65.0, 0.0, 99.31, 5.0, 'LegendNANA'],
#  ['2020-01-03T20:00', 6.9, 0.3, 63.0, 0.0, 99.39, 5.0, 'LegendNANA'],
#  ['2020-01-03T21:00', 6.8, 0.1, 63.0, 0.0, 99.4, 5.0, 'LegendNANA'],
#  ['2020-01-03T22:00', 6.5, 0.1, 63.0, 0.0, 99.44, 4.0, 'LegendNANA'],
#  ['2020-01-03T23:00', 6.4, -1.0, 59.0, 0.0, 99.53, 4.0, 'LegendNANA'],
#  ['2020-01-04T00:00', 5.9, -1.6, 59.0, 0.0, 99.6, 3.0, 'LegendNANA'],
#  ['2020-01-04T01:00', 5.1, -0.4, 68.0, 0.0, 99.63, 3.0, 'LegendNANA'],
#  ['2020-01-04T02:00', 4.6, -0.6, 69.0, 0.0, 99.64, 2.0, 'LegendNANA'],
#  ['2020-01-04T03:00', 4.2, -0.9, 69.0, 0.0, 99.58, 2.0, 'LegendNANA'],
#  ['2020-01-04T04:00', 4.1, -1.3, 68.0, 0.0, 99.59, 2.0, 'LegendNANA'],
#  ['2020-01-04T05:00', 3.8, -1.4, 69.0, 0.0, 99.51, 1.0, 'LegendNANA'],
#  ['2020-01-04T06:00', 3.7, -1.8, 68.0, 0.0, 99.5, 1.0, 'LegendNANA'],
#  ['2020-01-04T07:00', 3.2, -1.8, 70.0, 0.0, 99.46, 1.0, 'LegendNANA'],
#  ['2020-01-04T08:00', 3.0, -2.2, 68.0, 0.0, 99.5, 0.0, 'LegendNANA'],
#  ['2020-01-04T09:00', 2.6, -2.4, 69.0, 0.0, 99.47, 0, 'LegendNANA'],
#  ['2020-01-04T10:00', 1.4, -1.3, 82.0, 0.2, 99.46, 0, 'LegendNANA'],
#  ['2020-01-04T11:00', 0.9, -1.0, 87.0, 0.3, 99.44, 0, 'LegendNANA'],
#  ['2020-01-04T12:00', 0.8, -0.8, 89.0, 0.5, 99.42, 0, 'LegendNANA'],
#  ['2020-01-04T13:00', 0.9, -0.7, 89.0, 0.2, 99.46, 0, 'LegendNANA'],
#  ['2020-01-04T14:00', 0.9, -0.9, 87.0, 0.2, 99.47, 0, 'LegendNANA'],
#  ['2020-01-04T15:00', 1.4, -1.4, 82.0, 0.0, 99.53, 0, 'LegendNANA'],
#  ['2020-01-04T16:00', 1.8, -1.6, 78.0, 0.0, 99.48, 0, 'LegendNANA'],
#  ['2020-01-04T17:00', 2.5, -1.5, 75.0, 0.0, 99.38, 0, 'LegendNANA'],
#  ['2020-01-04T18:00', 2.6, -1.9, 72.0, 0.0, 99.32, 0, 'LegendNANA'],
#  ['2020-01-04T19:00', 2.6, -2.6, 68.0, 0.0, 99.26, 0, 'LegendNANA'],
#  ['2020-01-04T20:00', 3.0, -3.6, 62.0, 0.0, 99.26, 0.0, 'LegendNANA'],
#  ['2020-01-04T21:00', 3.0, -4.0, 60.0, 0.0, 99.29, 0, 'LegendNANA'],
#  ['2020-01-04T22:00', 2.6, -3.8, 63.0, 0.0, 99.36, 0, 'LegendNANA'],
#  ['2020-01-04T23:00', 2.5, -4.1, 62.0, 0.0, 99.45, 0, 'LegendNANA'],
#  ['2020-01-05T00:00', 2.0, -3.4, 67.0, 0.0, 99.49, 0, 'LegendNANA'],
#  ['2020-01-05T01:00', 1.0, -2.0, 81.0, 0.0, 99.56, 0, 'LegendNANA'],
#  ['2020-01-05T02:00', 0.7, -1.9, 82.0, 0.0, 99.57, 0, 'LegendNANA'],
#  ['2020-01-05T03:00', 0.9, -3.3, 73.0, 0.0, 99.57, 0, 'LegendNANA'],
#  ['2020-01-05T04:00', 0.8, -5.4, 63.0, 0.0, 99.6, 0, 'LegendNANA'],
#  ['2020-01-05T05:00', 0.7, -5.1, 65.0, 0.0, 99.62, 0, 'LegendNANA'],
#  ['2020-01-05T06:00', 0.3, -6.3, 61.0, 0.0, 99.68, 0, 'LegendNANA'],
#  ['2020-01-05T07:00', 0.5, -6.6, 59.0, 0.0, 99.73, 0, 'LegendNANA'],
#  ['2020-01-05T08:00', 0.5, -6.3, 60.0, 0.0, 99.82, 0, 'LegendNANA'],
#  ['2020-01-05T09:00', 0.4, -5.1, 67.0, 0.0, 99.9, 0, 'LegendNANA'],
#  ['2020-01-05T10:00', 0.3, -5.3, 66.0, 0.0, 99.95, 0, 'LegendNANA'],
#  ['2020-01-05T11:00', 0.0, -5.7, 66.0, 0.0, 100.03, 0, 'LegendNANA'],
#  ['2020-01-05T12:00', -0.2, -6.2, 64.0, 0.0, 100.1, 0, 'LegendNANA'],
#  ['2020-01-05T13:00', -0.9, -7.5, 61.0, 0.0, 100.19, 0, 'LegendNANA'],
#  ['2020-01-05T14:00', -0.2, -7.6, 58.0, 0.0, 100.29, 0, 'LegendNANA'],
#  ['2020-01-05T15:00', 0.2, -6.9, 59.0, 0.0, 100.35, 0, 'LegendNANA'],
#  ['2020-01-05T16:00', 1.2, -6.9, 55.0, 0.2, 100.31, 0, 'LegendNANA'],
#  ['2020-01-05T17:00', 1.3, -5.3, 61.0, 0.0, 100.21, 0, 'LegendNANA'],
#  ['2020-01-05T18:00', 1.7, -4.7, 63.0, 0.0, 100.13, 0, 'LegendNANA'],
#  ['2020-01-05T19:00', 1.5, -4.5, 64.0, 0.0, 100.09, 0, 'LegendNANA'],
#  ['2020-01-05T20:00', 1.6, -4.0, 66.0, 0.0, 100.01, 0, 'LegendNANA'],
#  ['2020-01-05T21:00', 1.6, -3.9, 67.0, 0.0, 99.94, 0, 'LegendNANA'],
#  ['2020-01-05T22:00', 1.7, -4.4, 64.0, 0.0, 99.89, 0, 'LegendNANA'],
#  ['2020-01-05T23:00', 1.2, -5.2, 62.0, 0.0, 99.9, 0, 'LegendNANA'],
#  ['2020-01-06T00:00', 0.0, -2.4, 84.0, 0.2, 99.88, 0, 'LegendNANA'],
#  ['2020-01-06T01:00', -0.3, -1.8, 90.0, 1.3, 99.83, 0, 'LegendNANA'],
#  ['2020-01-06T02:00', -0.2, -1.2, 92.0, 1.8, 99.73, 0, 'LegendNANA'],
#  ['2020-01-06T03:00', 0.0, -1.0, 93.0, 1.1, 99.59, 0, 'LegendNANA'],
#  ['2020-01-06T04:00', 0.3, -0.7, 93.0, 0.7, 99.49, 0, 'LegendNANA'],
#  ['2020-01-06T05:00', 0.7, -0.5, 92.0, 0.2, 99.37, 0, 'LegendNANA'],
#  ['2020-01-06T06:00', 1.2, -0.2, 90.0, 0.0, 99.24, 0, 'LegendNANA'],
#  ['2020-01-06T07:00', 1.6, 0.0, 89.0, 0.0, 99.23, 0, 'LegendNANA'],
#  ['2020-01-06T08:00', 1.5, -0.5, 87.0, 0.0, 99.29, 0, 'LegendNANA'],
#  ['2020-01-06T09:00', 1.5, -0.2, 88.0, 0.0, 99.31, 0, 'LegendNANA'],
#  ['2020-01-06T10:00', 1.9, -1.2, 80.0, 0.0, 99.36, 0, 'LegendNANA'],
#  ['2020-01-06T11:00', 2.0, -1.5, 78.0, 0.0, 99.42, 0, 'LegendNANA'],
#  ['2020-01-06T12:00', 2.2, -1.7, 76.0, 0.2, 99.47, 0, 'LegendNANA'],
#  ['2020-01-06T13:00', 1.7, -3.1, 71.0, 0.0, 99.57, 0, 'LegendNANA'],
#  ['2020-01-06T14:00', 1.8, -3.3, 69.0, 0.0, 99.68, 0, 'LegendNANA'],
#  ['2020-01-06T15:00', 2.3, -3.3, 66.0, 0.0, 99.78, 0, 'LegendNANA'],
#  ['2020-01-06T16:00', 2.1, -6.3, 53.0, 0.0, 99.82, 0, 'LegendNANA'],
#  ['2020-01-06T17:00', 2.1, -5.7, 56.0, 0.0, 99.79, 0, 'LegendNANA'],
#  ['2020-01-06T18:00', 2.2, -7.4, 49.0, 0.0, 99.75, 0, 'LegendNANA'],
#  ['2020-01-06T19:00', 2.2, -6.3, 53.0, 0.0, 99.72, 0, 'LegendNANA'],
#  ['2020-01-06T20:00', 2.2, -6.4, 53.0, 0.0, 99.71, 0, 'LegendNANA'],
#  ['2020-01-06T21:00', 2.2, -6.2, 54.0, 0.0, 99.73, 0, 'LegendNANA'],
#  ['2020-01-06T22:00', 2.6, -5.9, 53.0, 0.0, 99.72, 0, 'LegendNANA'],
#  ['2020-01-06T23:00', 2.7, -5.8, 54.0, 0.0, 99.8, 0, 'LegendNANA'],
#  ['2020-01-07T00:00', 1.4, -7.7, 51.0, 0.0, 99.95, 0, 'LegendNANA'],
#  ['2020-01-07T01:00', 0.3, -9.2, 49.0, 0.0, 100.02, 0, 'LegendNANA'],
#  ['2020-01-07T02:00', 0.3, -9.1, 49.0, 0.0, 100.05, 0, 'LegendNANA'],
#  ['2020-01-07T03:00', -0.3, -9.0, 51.0, 0.0, 100.09, 0, 'LegendNANA'],
#  ['2020-01-07T04:00', -0.8, -9.1, 54.0, 0.0, 100.11, 0, 'LegendNANA'],
#  ['2020-01-07T05:00', -1.2, -8.3, 59.0, 0.0, 100.15, 0, 'LegendNANA'],
#  ['2020-01-07T06:00', -1.7, -8.2, 61.0, 0.0, 100.16, 0, 'LegendNANA'],
#  ['2020-01-07T07:00', -1.7, -8.4, 60.0, 0.0, 100.2, 0, 'LegendNANA'],
#  ['2020-01-07T08:00', -1.6, -8.0, 61.0, 0.0, 100.22, 0, 'LegendNANA'],
#  ['2020-01-07T09:00', -1.5, -7.3, 65.0, 0.0, 100.18, 0, 'LegendNANA'],
#  ['2020-01-07T10:00', -2.8, -7.6, 69.0, 0.0, 100.16, 0, 'LegendNANA'],
#  ['2020-01-07T11:00', -2.5, -7.2, 70.0, 0.0, 100.13, 0, 'LegendNANA'],
#  ['2020-01-07T12:00', -2.9, -7.2, 72.0, 0.0, 100.09, 0, 'LegendNANA'],
#  ['2020-01-07T13:00', -1.0, -4.8, 76.0, 0.0, 100.03, 0, 'LegendNANA'],
#  ['2020-01-07T14:00', 0.7, -3.3, 75.0, 0.0, 100.0, 0, 'LegendNANA'],
#  ['2020-01-07T15:00', 1.0, -3.2, 73.0, 0.0, 100.09, 0, 'LegendNANA'],
#  ['2020-01-07T16:00', 1.4, -4.3, 66.0, 0.0, 100.04, 0, 'LegendNANA'],
#  ['2020-01-07T17:00', 2.4, -3.9, 63.0, 0.0, 99.92, 0, 'LegendNANA'],
#  ['2020-01-07T18:00', 2.5, -3.3, 65.0, 0.0, 99.79, 0, 'LegendNANA'],
#  ['2020-01-07T19:00', 3.0, -2.8, 66.0, 0.0, 99.73, 0.0, 'LegendNANA'],
#  ['2020-01-07T20:00', 3.4, -1.1, 72.0, 0.0, 99.71, 1.0, 'LegendNANA'],
#  ['2020-01-07T21:00', 3.8, -1.5, 69.0, 0.0, 99.69, 1.0, 'LegendNANA'],
#  ['2020-01-07T22:00', 3.0, -1.3, 73.0, 0.0, 99.68, 1.0, 'LegendNANA'],
#  ['2020-01-07T23:00', 3.2, -0.7, 76.0, 0.0, 99.65, 1.0, 'LegendNANA'],
#  ['2020-01-08T00:00', 3.0, -1.4, 73.0, 0.0, 99.61, 1.0, 'LegendNANA'],
#  ['2020-01-08T01:00', 2.7, -1.1, 76.0, 0.0, 99.55, 0.0, 'LegendNANA'],
#  ['2020-01-08T02:00', 2.6, -2.3, 70.0, 0.0, 99.54, 0, 'LegendNANA'],
#  ['2020-01-08T03:00', 2.0, -2.3, 73.0, 0.0, 99.54, 0, 'LegendNANA'],
#  ['2020-01-08T04:00', 1.5, -2.6, 74.0, 0.0, 99.5, 0, 'LegendNANA'],
#  ['2020-01-08T05:00', 0.9, -3.0, 75.0, 0.0, 99.48, 0, 'LegendNANA'],
#  ['2020-01-08T06:00', 0.5, -3.7, 74.0, 0.0, 99.43, 0, 'LegendNANA'],
#  ['2020-01-08T07:00', 0.4, -3.8, 73.0, 0.0, 99.43, 0, 'LegendNANA'],
#  ['2020-01-08T08:00', -0.5, -2.8, 84.0, 0.3, 99.5, 0, 'LegendNANA'],
#  ['2020-01-08T09:00', -1.2, -2.7, 89.0, 1.0, 99.47, 0, 'LegendNANA'],
#  ['2020-01-08T10:00', -1.5, -4.3, 81.0, 0.0, 99.46, 0, 'LegendNANA'],
#  ['2020-01-08T11:00', -1.7, -4.9, 79.0, 0.0, 99.6, 0, 'LegendNANA'],
#  ['2020-01-08T12:00', -2.5, -8.1, 65.0, 0.0, 99.71, 0, 'LegendNANA'],
#  ['2020-01-08T13:00', -3.1, -9.2, 62.0, 0.0, 99.86, 0, 'LegendNANA'],
#  ['2020-01-08T14:00', -3.2, -7.9, 70.0, 0.0, 100.0, 0, 'LegendNANA'],
#  ['2020-01-08T15:00', -3.1, -10.2, 58.0, 0.0, 100.15, 0, 'LegendNANA'],
#  ['2020-01-08T16:00', -2.9, -11.8, 50.0, 0.0, 100.31, 0, 'LegendNANA'],
#  ['2020-01-08T17:00', -2.9, -14.3, 41.0, 0.0, 100.42, 0, 'LegendNANA'],
#  ['2020-01-08T18:00', -3.3, -14.1, 43.0, 0.2, 100.51, 0, 'LegendNANA'],
#  ['2020-01-08T19:00', -4.0, -14.4, 45.0, 0.0, 100.64, 0, 'LegendNANA'],
#  ['2020-01-08T20:00', -4.2, -13.4, 48.0, 0.0, 100.82, 0, 'LegendNANA'],
#  ['2020-01-08T21:00', -5.0, -14.9, 46.0, 0.0, 101.04, 0, 'LegendNANA'],
#  ['2020-01-08T22:00', -5.8, -13.7, 54.0, 0.0, 101.23, 0, 'LegendNANA'],
#  ['2020-01-08T23:00', -6.3, -15.2, 49.0, 0.0, 101.38, 0, 'LegendNANA'],
#  ['2020-01-09T00:00', -7.0, -15.3, 51.0, 0.0, 101.54, 0, 'LegendNANA'],
#  ['2020-01-09T01:00', -7.1, -15.1, 53.0, 0.0, 101.66, 0, 'LegendNANA'],
#  ['2020-01-09T02:00', -7.1, -14.9, 54.0, 0.0, 101.79, 0, 'LegendNANA'],
#  ['2020-01-09T03:00', -6.9, -14.5, 55.0, 0.0, 101.88, 0, 'LegendNANA'],
#  ['2020-01-09T04:00', -7.0, -15.2, 52.0, 0.0, 102.0, 0, 'LegendNANA'],
#  ['2020-01-09T05:00', -7.0, -14.8, 54.0, 0.0, 102.08, 0, 'LegendNANA'],
#  ['2020-01-09T06:00', -7.8, -15.2, 55.0, 0.0, 102.09, 0, 'LegendNANA'],
#  ['2020-01-09T07:00', -8.1, -15.2, 57.0, 0.0, 102.15, 0, 'LegendNANA'],
#  ['2020-01-09T08:00', -8.2, -14.8, 59.0, 0.0, 102.22, 0, 'LegendNANA'],
#  ['2020-01-09T09:00', -8.6, -13.8, 66.0, 0.0, 102.25, 0, 'LegendNANA'],
#  ['2020-01-09T10:00', -9.2, -14.2, 67.0, 0.0, 102.3, 0, 'LegendNANA'],
#  ['2020-01-09T11:00', -9.4, -14.0, 69.0, 0.0, 102.38, 0, 'LegendNANA'],
#  ['2020-01-09T12:00', -9.6, -14.4, 68.0, 0.0, 102.42, 0, 'LegendNANA'],
#  ['2020-01-09T13:00', -9.5, -13.2, 74.0, 0.0, 102.42, 0, 'LegendNANA'],
#  ['2020-01-09T14:00', -8.0, -10.8, 80.0, 0.0, 102.43, 0, 'LegendNANA'],
#  ['2020-01-09T15:00', -5.5, -8.2, 82.0, 0.0, 102.36, 0, 'LegendNANA'],
#  ['2020-01-09T16:00', -4.8, -9.8, 68.0, 0.0, 102.3, 0, 'LegendNANA'],
#  ['2020-01-09T17:00', -4.3, -10.5, 62.0, 0.0, 102.14, 0, 'LegendNANA'],
#  ['2020-01-09T18:00', -4.4, -10.3, 63.0, 0.0, 101.97, 0, 'LegendNANA'],
#  ['2020-01-09T19:00', -3.8, -9.6, 64.0, 0.0, 101.8, 0, 'LegendNANA'],
#  ['2020-01-09T20:00', -3.6, -9.1, 65.0, 0.0, 101.75, 0, 'LegendNANA'],
#  ['2020-01-09T21:00', -2.9, -9.3, 61.0, 0.0, 101.65, 0, 'LegendNANA'],
#  ['2020-01-09T22:00', -2.2, -9.0, 59.0, 0.0, 101.55, 0, 'LegendNANA'],
#  ['2020-01-09T23:00', -1.5, -8.3, 60.0, 0.0, 101.46, 0, 'LegendNANA'],
#  ['2020-01-10T00:00', -0.9, -7.5, 61.0, 0.0, 101.29, 0, 'LegendNANA'],
#  ['2020-01-10T01:00', 0.1, -6.4, 62.0, 0.0, 101.17, 0, 'LegendNANA'],
#  ['2020-01-10T02:00', 0.7, -6.1, 60.0, 0.0, 101.04, 0, 'LegendNANA'],
#  ['2020-01-10T03:00', 1.4, -5.7, 59.0, 0.0, 100.93, 0, 'LegendNANA'],
#  ['2020-01-10T04:00', 2.0, -6.0, 55.0, 0.0, 100.87, 0, 'LegendNANA'],
#  ['2020-01-10T05:00', 2.6, -5.3, 56.0, 0.0, 100.75, 0, 'LegendNANA'],
#  ['2020-01-10T06:00', 3.3, -4.0, 59.0, 0.0, 100.66, 0.0, 'LegendNANA'],
#  ['2020-01-10T07:00', 4.7, -1.7, 63.0, 0.0, 100.63, 2.0, 'LegendNANA'],
#  ['2020-01-10T08:00', 5.4, -0.3, 67.0, 0.0, 100.68, 3.0, 'LegendNANA'],
#  ['2020-01-10T09:00', 6.3, 0.5, 66.0, 0.0, 100.68, 4.0, 'LegendNANA'],
#  ['2020-01-10T10:00', 7.0, 1.7, 69.0, 0.0, 100.69, 5.0, 'LegendNANA'],
#  ['2020-01-10T11:00', 5.8, 3.2, 83.0, 0.0, 100.74, 5.0, 'LegendNANA'],
#  ['2020-01-10T12:00', 5.0, 3.1, 87.0, 0.0, 100.78, 4.0, 'LegendNANA'],
#  ['2020-01-10T13:00', 5.1, 3.3, 88.0, 0.0, 100.8, 4.0, 'LegendNANA'],
#  ['2020-01-10T14:00', 5.3, 3.4, 88.0, 0.0, 100.91, 4.0, 'LegendNANA'],
#  ['2020-01-10T15:00', 5.4, 3.9, 90.0, 0.0, 100.92, 4.0, 'LegendNANA'],
#  ['2020-01-10T16:00', 5.8, 4.0, 88.0, 0.0, 100.93, 5.0, 'LegendNANA'],
#  ['2020-01-10T17:00', 6.2, 4.2, 87.0, 0.0, 100.88, 5.0, 'LegendNANA'],
#  ['2020-01-10T18:00', 6.5, 4.5, 87.0, 0.0, 100.81, 6.0, 'LegendNANA'],
#  ['2020-01-10T19:00', 6.5, 4.6, 87.0, 0.0, 100.8, 6.0, 'LegendNANA'],
#  ['2020-01-10T20:00', 6.8, 5.2, 90.0, 0.0, 100.79, 6.0, 'LegendNANA'],
#  ['2020-01-10T21:00', 6.9, 5.3, 89.0, 0.0, 100.86, 6.0, 'LegendNANA'],
#  ['2020-01-10T22:00', 6.6, 5.1, 90.0, 0.0, 100.89, 6.0, 'LegendNANA'],
#  ['2020-01-10T23:00', 7.2, 5.8, 91.0, 0.0, 100.92, 7.0, 'LegendNANA'],
#  ['2020-01-11T00:00', 6.8, 5.5, 92.0, 0.0, 100.91, 6.0, 'LegendNANA'],
#  ['2020-01-11T01:00', 7.0, 5.8, 92.0, 0.0, 100.9, 7.0, 'LegendNANA'],
#  ['2020-01-11T02:00', 7.0, 5.8, 92.0, 0.0, 100.91, 7.0, 'LegendNANA'],
#  ['2020-01-11T03:00', 7.4, 6.2, 92.0, 0.0, 100.87, 7.0, 'LegendNANA'],
#  ['2020-01-11T04:00', 7.5, 6.4, 93.0, 0.0, 100.75, 7.0, 'LegendNANA'],
#  ['2020-01-11T05:00', 7.1, 6.0, 93.0, 0.8, 100.61, 7.0, 'LegendNANA'],
#  ['2020-01-11T06:00', 7.0, 6.0, 93.0, 0.3, 100.46, 7.0, 'LegendNANA'],
#  ['2020-01-11T07:00', 7.4, 6.4, 93.0, 1.0, 100.36, 7.0, 'LegendNANA'],
#  ['2020-01-11T08:00', 7.7, 6.7, 93.0, 2.7, 100.27, 8.0, 'LegendNANA'],
#  ['2020-01-11T09:00', 7.8, 6.8, 93.0, 1.8, 100.14, 8.0, 'LegendNANA'],
#  ['2020-01-11T10:00', 9.5, 8.4, 93.0, 1.9, 99.94, 10.0, 'LegendNANA'],
#  ['2020-01-11T11:00', 9.7, 8.6, 93.0, 0.2, 99.8, 10.0, 'LegendNANA'],
#  ['2020-01-11T12:00', 9.6, 8.3, 91.0, 0.9, 99.68, 10.0, 'LegendNANA'],
#  ['2020-01-11T13:00', 9.9, 8.2, 89.0, 0.0, 99.56, 10.0, 'LegendNANA'],
#  ['2020-01-11T14:00', 11.2, 8.4, 83.0, 0.0, 99.52, 12.0, 'LegendNANA'],
#  ['2020-01-11T15:00', 11.0, 8.8, 86.0, 3.1, 99.66, 12.0, 'LegendNANA'],
#  ['2020-01-11T16:00', 11.3, 9.7, 90.0, 2.9, 99.61, 12.0, 'LegendNANA'],
#  ['2020-01-11T17:00', 11.6, 10.1, 91.0, 1.6, 99.58, 13.0, 'LegendNANA'],
#  ['2020-01-11T18:00', 4.9, 3.4, 90.0, 3.0, 99.59, 4.0, 'LegendNANA'],
#  ['2020-01-11T19:00', 4.8, 3.1, 89.0, 7.0, 99.47, 3.0, 'LegendNANA'],
#  ['2020-01-11T20:00', 4.5, 2.8, 89.0, 3.9, 99.48, 3.0, 'LegendNANA'],
#  ['2020-01-11T21:00', 4.4, 2.8, 89.0, 3.4, 99.43, 3.0, 'LegendNANA'],
#  ['2020-01-11T22:00', 4.2, 2.6, 90.0, 5.9, 99.57, 3.0, 'LegendNANA'],
#  ['2020-01-11T23:00', 3.8, 2.3, 90.0, 4.2, 99.58, 2.0, 'LegendNANA'],
#  ['2020-01-12T00:00', 3.6, 2.1, 90.0, 1.4, 99.63, 2.0, 'LegendNANA'],
#  ['2020-01-12T01:00', 3.4, 1.9, 90.0, 1.5, 99.64, 2.0, 'LegendNANA'],
#  ['2020-01-12T02:00', 3.1, 1.6, 90.0, 2.3, 99.51, 1.0, 'LegendNANA'],
#  ['2020-01-12T03:00', 3.1, 1.7, 90.0, 2.1, 99.55, 1.0, 'LegendNANA'],
#  ['2020-01-12T04:00', 2.7, 1.4, 91.0, 2.1, 99.43, 1.0, 'LegendNANA'],
#  ['2020-01-12T05:00', 2.5, 1.2, 91.0, 1.3, 99.25, 1.0, 'LegendNANA'],
#  ['2020-01-12T06:00', 2.2, 0.9, 91.0, 1.2, 99.05, 0.0, 'LegendNANA'],
#  ['2020-01-12T07:00', 1.8, 0.4, 91.0, 4.3, 98.97, 0, 'LegendNANA'],
#  ['2020-01-12T08:00', 1.6, 0.3, 91.0, 3.5, 99.01, 0, 'LegendNANA'],
#  ['2020-01-12T09:00', 1.3, -0.1, 91.0, 2.1, 98.81, 0, 'LegendNANA'],
#  ['2020-01-12T10:00', 1.4, 0.1, 91.0, 0.7, 99.08, 0, 'LegendNANA'],
#  ['2020-01-12T11:00', -0.4, -2.1, 89.0, 1.7, 99.47, 0, 'LegendNANA'],
#  ['2020-01-12T12:00', -4.0, -6.3, 84.0, 0.3, 99.85, 0, 'LegendNANA'],
#  ['2020-01-12T13:00', -4.5, -7.6, 79.0, 0.0, 100.15, 0, 'LegendNANA'],
#  ['2020-01-12T14:00', -5.0, -8.7, 75.0, 0.0, 100.51, 0, 'LegendNANA'],
#  ['2020-01-12T15:00', -4.1, -9.0, 69.0, 0.3, 100.81, 0, 'LegendNANA'],
#  ['2020-01-12T16:00', -4.7, -10.1, 66.0, 0.0, 101.07, 0, 'LegendNANA'],
#  ['2020-01-12T17:00', -3.8, -8.9, 67.0, 0.0, 101.17, 0, 'LegendNANA'],
#  ['2020-01-12T18:00', -4.1, -9.4, 67.0, 0.0, 101.2, 0, 'LegendNANA'],
#  ['2020-01-12T19:00', -3.5, -8.4, 69.0, 0.0, 101.34, 0, 'LegendNANA'],
#  ['2020-01-12T20:00', -3.3, -8.0, 70.0, 0.0, 101.42, 0, 'LegendNANA'],
#  ['2020-01-12T21:00', -3.2, -7.9, 70.0, 0.0, 101.56, 0, 'LegendNANA'],
#  ['2020-01-12T22:00', -3.3, -7.8, 71.0, 0.0, 101.63, 0, 'LegendNANA'],
#  ['2020-01-12T23:00', -3.4, -7.8, 72.0, 0.0, 101.7, 0, 'LegendNANA'],
#  ['2020-01-13T00:00', -3.8, -8.1, 72.0, 0.0, 101.67, 0, 'LegendNANA'],
#  ['2020-01-13T01:00', -3.6, -7.6, 74.0, 0.0, 101.66, 0, 'LegendNANA'],
#  ['2020-01-13T02:00', -3.9, -7.8, 74.0, 0.0, 101.64, 0, 'LegendNANA'],
#  ['2020-01-13T03:00', -4.0, -7.7, 75.0, 0.0, 101.65, 0, 'LegendNANA'],
#  ['2020-01-13T04:00', -4.2, -7.8, 76.0, 0.0, 101.6, 0, 'LegendNANA'],
#  ['2020-01-13T05:00', -4.4, -7.5, 79.0, 0.0, 101.56, 0, 'LegendNANA'],
#  ['2020-01-13T06:00', -4.4, -7.1, 82.0, 0.0, 101.51, 0, 'LegendNANA'],
#  ['2020-01-13T07:00', -4.1, -6.0, 86.0, 0.0, 101.44, 0, 'LegendNANA'],
#  ['2020-01-13T08:00', -3.0, -4.8, 88.0, 0.0, 101.32, 0, 'LegendNANA'],
#  ['2020-01-13T09:00', -1.8, -3.7, 87.0, 0.0, 101.27, 0, 'LegendNANA'],
#  ['2020-01-13T10:00', -3.5, -5.4, 87.0, 0.0, 101.27, 0, 'LegendNANA'],
#  ['2020-01-13T11:00', -3.4, -4.8, 90.0, 0.0, 101.18, 0, 'LegendNANA'],
#  ['2020-01-13T12:00', -2.7, -4.2, 90.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-01-13T13:00', -2.0, -3.4, 90.0, 0.0, 101.17, 0, 'LegendNANA'],
#  ['2020-01-13T14:00', -1.2, -2.5, 91.0, 0.0, 101.18, 0, 'LegendNANA'],
#  ['2020-01-13T15:00', -0.5, -1.8, 91.0, 0.0, 101.2, 0, 'LegendNANA'],
#  ['2020-01-13T16:00', -0.5, -1.9, 90.0, 0.0, 101.25, 0, 'LegendNANA'],
#  ['2020-01-13T17:00', -0.1, -1.7, 89.0, 0.0, 101.2, 0, 'LegendNANA'],
#  ['2020-01-13T18:00', 0.6, -1.1, 89.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-01-13T19:00', 1.0, -0.8, 88.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-01-13T20:00', 1.5, -0.4, 87.0, 0.0, 101.22, 0, 'LegendNANA'],
#  ['2020-01-13T21:00', 1.6, -0.4, 87.0, 0.0, 101.29, 0, 'LegendNANA'],
#  ['2020-01-13T22:00', 1.6, -0.4, 87.0, 0.0, 101.35, 0, 'LegendNANA'],
#  ['2020-01-13T23:00', 1.7, -0.2, 87.0, 0.0, 101.39, 0, 'LegendNANA'],
#  ['2020-01-14T00:00', 1.9, -0.1, 86.0, 0.0, 101.45, 0, 'LegendNANA'],
#  ['2020-01-14T01:00', 2.3, 0.2, 86.0, 0.0, 101.49, 0.0, 'LegendNANA'],
#  ['2020-01-14T02:00', 2.3, -0.2, 84.0, 0.0, 101.48, 0.0, 'LegendNANA'],
#  ['2020-01-14T03:00', 1.8, -0.7, 83.0, 0.0, 101.51, 0, 'LegendNANA'],
#  ['2020-01-14T04:00', 1.4, -1.0, 84.0, 0.0, 101.55, 0, 'LegendNANA'],
#  ['2020-01-14T05:00', 1.2, -1.3, 83.0, 0.0, 101.52, 0, 'LegendNANA'],
#  ['2020-01-14T06:00', 0.9, -1.6, 84.0, 0.0, 101.47, 0, 'LegendNANA'],
#  ['2020-01-14T07:00', 0.8, -1.9, 82.0, 0.0, 101.47, 0, 'LegendNANA'],
#  ['2020-01-14T08:00', 0.6, -2.4, 80.0, 0.0, 101.43, 0, 'LegendNANA'],
#  ['2020-01-14T09:00', 0.7, -1.8, 84.0, 0.0, 101.3, 0, 'LegendNANA'],
#  ['2020-01-14T10:00', 0.9, -2.2, 80.0, 0.0, 101.19, 0, 'LegendNANA'],
#  ['2020-01-14T11:00', 1.0, -1.5, 83.0, 0.0, 101.1, 0, 'LegendNANA'],
#  ['2020-01-14T12:00', 1.1, -1.2, 84.0, 0.0, 100.99, 0, 'LegendNANA'],
#  ['2020-01-14T13:00', 1.4, -0.9, 85.0, 0.0, 100.86, 0, 'LegendNANA'],
#  ['2020-01-14T14:00', 2.1, -0.1, 86.0, 0.0, 100.87, 0, 'LegendNANA'],
#  ['2020-01-14T15:00', 2.3, 0.0, 85.0, 0.0, 100.79, 0.0, 'LegendNANA'],
#  ['2020-01-14T16:00', nan, nan, nan, nan, nan, nan, nan],
#  ['2020-01-14T17:00', nan, nan, nan, nan, nan, nan, nan],
#  ['2020-01-14T18:00', 2.5, 0.1, 84.0, 0.0, 100.35, 0.0, 'LegendNANA'],
#  ['2020-01-14T19:00', 1.5, -0.4, 87.0, 0.0, 100.2, 0, 'LegendNANA'],
#  ['2020-01-14T20:00', 1.2, -0.3, 90.0, 0.0, 100.17, 0, 'LegendNANA'],
#  ['2020-01-14T21:00', 1.3, -0.1, 91.0, 0.0, 100.23, 0, 'LegendNANA'],
#  ['2020-01-14T22:00', 1.1, -0.1, 92.0, 0.0, 100.26, 0, 'LegendNANA'],
#  ['2020-01-14T23:00', 1.4, 0.3, 92.0, 0.0, 100.33, 0, 'LegendNANA'],
#  ['2020-01-15T00:00', 2.0, 0.9, 93.0, 0.0, 100.34, 0.0, 'LegendNANA'],
#  ['2020-01-15T01:00', 2.8, 1.4, 91.0, 0.0, 100.37, 1.0, 'LegendNANA'],
#  ['2020-01-15T02:00', 2.9, 1.5, 90.0, 0.0, 100.43, 1.0, 'LegendNANA'],
#  ['2020-01-15T03:00', 3.3, 1.7, 89.0, 0.0, 100.43, 2.0, 'LegendNANA'],
#  ['2020-01-15T04:00', 3.5, 0.7, 82.0, 0.0, 100.48, 2.0, 'LegendNANA'],
#  ['2020-01-15T05:00', 4.0, 0.0, 75.0, 0.0, 100.52, 2.0, 'LegendNANA'],
#  ['2020-01-15T06:00', 3.8, -0.6, 73.0, 0.0, 100.55, 1.0, 'LegendNANA'],
#  ['2020-01-15T07:00', 3.8, -1.2, 70.0, 0.0, 100.58, 1.0, 'LegendNANA'],
#  ['2020-01-15T08:00', 3.7, -2.2, 65.0, 0.0, 100.63, 1.0, 'LegendNANA'],
#  ['2020-01-15T09:00', 3.6, -2.7, 63.0, 0.0, 100.72, 1.0, 'LegendNANA'],
#  ['2020-01-15T10:00', 3.5, -2.6, 64.0, 0.0, 100.77, 1.0, 'LegendNANA'],
#  ['2020-01-15T11:00', 3.5, -2.9, 63.0, 0.0, 100.75, 1.0, 'LegendNANA'],
#  ['2020-01-15T12:00', 3.3, -2.8, 64.0, 0.0, 100.73, 1.0, 'LegendNANA'],
#  ['2020-01-15T13:00', 2.9, -2.6, 67.0, 0.0, 100.75, 0.0, 'LegendNANA'],
#  ['2020-01-15T14:00', 3.4, -2.2, 67.0, 0.0, 100.78, 1.0, 'LegendNANA'],
#  ['2020-01-15T15:00', 3.7, -1.8, 67.0, 0.0, 100.86, 1.0, 'LegendNANA'],
#  ['2020-01-15T16:00', 3.9, -3.0, 61.0, 0.0, 100.83, 1.0, 'LegendNANA'],
#  ['2020-01-15T17:00', 4.2, -2.9, 60.0, 0.0, 100.78, 1.0, 'LegendNANA'],
#  ['2020-01-15T18:00', 4.6, -3.3, 57.0, 0.0, 100.7, 2.0, 'LegendNANA'],
#  ['2020-01-15T19:00', 4.2, -3.0, 59.0, 0.0, 100.68, 1.0, 'LegendNANA'],
#  ['2020-01-15T20:00', 4.1, -3.0, 60.0, 0.0, 100.59, 1.0, 'LegendNANA'],
#  ['2020-01-15T21:00', 4.2, -2.7, 61.0, 0.0, 100.54, 1.0, 'LegendNANA'],
#  ['2020-01-15T22:00', 4.0, -2.8, 61.0, 0.0, 100.44, 1.0, 'LegendNANA'],
#  ['2020-01-15T23:00', 3.8, -2.9, 62.0, 0.0, 100.37, 1.0, 'LegendNANA'],
#  ['2020-01-16T00:00', 3.6, -3.5, 60.0, 0.0, 100.26, 1.0, 'LegendNANA'],
#  ['2020-01-16T01:00', 3.3, -1.3, 72.0, 0.0, 100.29, 1.0, 'LegendNANA'],
#  ['2020-01-16T02:00', 3.3, -1.2, 72.0, 0.0, 100.07, 1.0, 'LegendNANA'],
#  ['2020-01-16T03:00', 3.4, -0.6, 75.0, 0.0, 100.06, 1.0, 'LegendNANA'],
#  ['2020-01-16T04:00', 3.4, -0.3, 77.0, 0.0, 99.92, 1.0, 'LegendNANA'],
#  ['2020-01-16T05:00', 3.4, -0.2, 77.0, 0.0, 99.9, 1.0, 'LegendNANA'],
#  ['2020-01-16T06:00', 2.5, -0.5, 81.0, 0.0, 99.85, 0.0, 'LegendNANA'],
#  ['2020-01-16T07:00', 2.2, -0.8, 81.0, 0.0, 99.91, 0, 'LegendNANA'],
#  ['2020-01-16T08:00', 1.3, -0.6, 87.0, 0.0, 100.0, 0, 'LegendNANA'],
#  ['2020-01-16T09:00', 1.3, -0.9, 86.0, 0.0, 100.08, 0, 'LegendNANA'],
#  ['2020-01-16T10:00', 1.1, -1.3, 85.0, 0.0, 100.15, 0, 'LegendNANA'],
#  ['2020-01-16T11:00', 1.4, -0.9, 85.0, 0.0, 100.29, 0, 'LegendNANA'],
#  ['2020-01-16T12:00', 1.1, -2.1, 79.0, 0.0, 100.4, 0, 'LegendNANA'],
#  ['2020-01-16T13:00', 1.2, -3.9, 69.0, 0.0, 100.48, 0, 'LegendNANA'],
#  ['2020-01-16T14:00', 1.0, -4.6, 66.0, 0.0, 100.56, 0, 'LegendNANA'],
#  ['2020-01-16T15:00', 1.5, -4.7, 63.0, 0.0, 100.66, 0, 'LegendNANA'],
#  ['2020-01-16T16:00', 2.4, -5.2, 57.0, 0.0, 100.72, 0, 'LegendNANA'],
#  ['2020-01-16T17:00', 1.7, -5.6, 58.0, 0.0, 100.75, 0, 'LegendNANA'],
#  ['2020-01-16T18:00', 1.9, -5.6, 57.0, 0.0, 100.77, 0, 'LegendNANA'],
#  ['2020-01-16T19:00', 0.9, -6.1, 60.0, 0.0, 100.85, 0, 'LegendNANA'],
#  ['2020-01-16T20:00', -0.7, -7.2, 61.0, 0.0, 100.99, 0, 'LegendNANA'],
#  ['2020-01-16T21:00', -1.6, -9.4, 55.0, 0.0, 101.14, 0, 'LegendNANA'],
#  ['2020-01-16T22:00', -2.9, -9.9, 58.0, 0.0, 101.28, 0, 'LegendNANA'],
#  ['2020-01-16T23:00', -3.4, -9.0, 65.0, 0.0, 101.43, 0, 'LegendNANA'],
#  ['2020-01-17T00:00', -4.3, -10.2, 63.0, 0.0, 101.6, 0, 'LegendNANA'],
#  ['2020-01-17T01:00', -4.9, -10.4, 66.0, 0.0, 101.73, 0, 'LegendNANA'],
#  ['2020-01-17T02:00', -6.6, -13.1, 59.0, 0.0, 101.91, 0, 'LegendNANA'],
#  ['2020-01-17T03:00', -7.5, -14.4, 58.0, 0.0, 102.03, 0, 'LegendNANA'],
#  ['2020-01-17T04:00', -8.7, -15.4, 58.0, 0.0, 102.18, 0, 'LegendNANA'],
#  ['2020-01-17T05:00', -9.5, -15.8, 60.0, 0.0, 102.35, 0, 'LegendNANA'],
#  ['2020-01-17T06:00', -10.4, -17.7, 55.0, 0.0, 102.45, 0, 'LegendNANA'],
#  ['2020-01-17T07:00', -10.8, -18.3, 54.0, 0.0, 102.56, 0, 'LegendNANA'],
#  ['2020-01-17T08:00', -11.6, -19.0, 54.0, 0.0, 102.68, 0, 'LegendNANA'],
#  ['2020-01-17T09:00', -12.2, -19.4, 55.0, 0.0, 102.76, 0, 'LegendNANA'],
#  ['2020-01-17T10:00', -12.6, -19.3, 58.0, 0.0, 102.86, 0, 'LegendNANA'],
#  ['2020-01-17T11:00', -13.2, -19.6, 59.0, 0.0, 102.97, 0, 'LegendNANA'],
#  ['2020-01-17T12:00', -13.2, -19.3, 60.0, 0.0, 103.08, 0, 'LegendNANA'],
#  ['2020-01-17T13:00', -13.4, -18.6, 65.0, 0.0, 103.12, 0, 'LegendNANA'],
#  ['2020-01-17T14:00', -12.9, -18.4, 64.0, 0.0, 103.14, 0, 'LegendNANA'],
#  ['2020-01-17T15:00', -11.3, -17.9, 58.0, 0.0, 103.13, 0, 'LegendNANA'],
#  ['2020-01-17T16:00', -9.6, -17.5, 52.0, 0.0, 103.16, 0, 'LegendNANA'],
#  ['2020-01-17T17:00', -9.0, -18.2, 47.0, 0.0, 103.06, 0, 'LegendNANA'],
#  ['2020-01-17T18:00', -7.7, -17.0, 47.0, 0.0, 102.95, 0, 'LegendNANA'],
#  ['2020-01-17T19:00', -7.3, -16.3, 49.0, 0.0, 102.87, 0, 'LegendNANA'],
#  ['2020-01-17T20:00', -7.9, -15.1, 56.0, 0.0, 102.79, 0, 'LegendNANA'],
#  ['2020-01-17T21:00', -8.2, -14.3, 61.0, 0.0, 102.78, 0, 'LegendNANA'],
#  ['2020-01-17T22:00', -8.2, -14.0, 63.0, 0.0, 102.77, 0, 'LegendNANA'],
#  ['2020-01-17T23:00', -8.2, -13.5, 66.0, 0.0, 102.74, 0, 'LegendNANA'],
#  ['2020-01-18T00:00', -7.9, -13.2, 65.0, 0.0, 102.74, 0, 'LegendNANA'],
#  ['2020-01-18T01:00', -7.8, -13.1, 66.0, 0.0, 102.73, 0, 'LegendNANA'],
#  ['2020-01-18T02:00', -7.6, -12.5, 68.0, 0.0, 102.63, 0, 'LegendNANA'],
#  ['2020-01-18T03:00', -7.7, -13.0, 66.0, 0.0, 102.58, 0, 'LegendNANA'],
#  ['2020-01-18T04:00', -7.7, -12.9, 66.0, 0.0, 102.5, 0, 'LegendNANA'],
#  ['2020-01-18T05:00', -7.6, -13.1, 65.0, 0.0, 102.47, 0, 'LegendNANA'],
#  ['2020-01-18T06:00', -7.4, -12.4, 67.0, 0.0, 102.31, 0, 'LegendNANA'],
#  ['2020-01-18T07:00', -7.1, -12.0, 68.0, 0.0, 102.21, 0, 'LegendNANA'],
#  ['2020-01-18T08:00', -5.3, -9.5, 73.0, 0.0, 102.08, 0, 'LegendNANA'],
#  ['2020-01-18T09:00', -5.7, -10.2, 71.0, 0.0, 101.79, 0, 'LegendNANA'],
#  ['2020-01-18T10:00', -5.3, -10.6, 66.0, 0.0, 101.61, 0, 'LegendNANA'],
#  ['2020-01-18T11:00', -4.9, -9.8, 69.0, 0.0, 101.39, 0, 'LegendNANA'],
#  ['2020-01-18T12:00', -4.5, -10.2, 64.0, 0.0, 101.2, 0, 'LegendNANA'],
#  ['2020-01-18T13:00', -4.1, -8.3, 72.0, 0.0, 101.0, 0, 'LegendNANA'],
#  ['2020-01-18T14:00', -3.5, -7.6, 73.0, 0.0, 100.79, 0, 'LegendNANA'],
#  ['2020-01-18T15:00', -3.1, -7.9, 69.0, 0.0, 100.62, 0, 'LegendNANA'],
#  ['2020-01-18T16:00', -3.9, -5.3, 90.0, 0.6, 100.42, 0, 'LegendNANA'],
#  ['2020-01-18T17:00', -3.5, -4.5, 93.0, 2.7, 100.07, 0, 'LegendNANA'],
#  ['2020-01-18T18:00', -3.3, -4.2, 93.0, 2.0, 99.76, 0, 'LegendNANA'],
#  ['2020-01-18T19:00', -2.6, -3.4, 94.0, 2.5, 99.45, 0, 'LegendNANA'],
#  ['2020-01-18T20:00', -1.7, -2.5, 95.0, 1.9, 99.21, 0, 'LegendNANA'],
#  ['2020-01-18T21:00', -1.3, -2.0, 95.0, 2.0, 98.93, 0, 'LegendNANA'],
#  ['2020-01-18T22:00', -0.6, -1.2, 96.0, 2.2, 98.76, 0, 'LegendNANA'],
#  ['2020-01-18T23:00', 0.0, -0.6, 96.0, 1.2, 98.57, 0, 'LegendNANA'],
#  ['2020-01-19T00:00', 0.6, 0.0, 96.0, 0.9, 98.49, 0, 'LegendNANA'],
#  ['2020-01-19T01:00', 1.6, 1.0, 96.0, 0.3, 98.43, 0, 'LegendNANA'],
#  ['2020-01-19T02:00', 1.9, 1.3, 96.0, 0.0, 98.52, 0.0, 'LegendNANA'],
#  ['2020-01-19T03:00', 2.4, 0.7, 88.0, 0.0, 98.58, 0.0, 'LegendNANA'],
#  ['2020-01-19T04:00', 2.2, -2.0, 74.0, 0.0, 98.62, 0, 'LegendNANA'],
#  ['2020-01-19T05:00', 1.7, -2.4, 74.0, 0.0, 98.65, 0, 'LegendNANA'],
#  ['2020-01-19T06:00', 1.3, -2.9, 74.0, 0.0, 98.67, 0, 'LegendNANA'],
#  ['2020-01-19T07:00', 1.1, -3.0, 74.0, 0.0, 98.73, 0, 'LegendNANA'],
#  ['2020-01-19T08:00', 0.9, -3.1, 75.0, 0.0, 98.81, 0, 'LegendNANA'],
#  ['2020-01-19T09:00', 1.0, -3.0, 75.0, 0.0, 98.91, 0, 'LegendNANA'],
#  ['2020-01-19T10:00', 0.1, -1.8, 87.0, 0.3, 99.01, 0, 'LegendNANA'],
#  ['2020-01-19T11:00', -0.2, -3.4, 79.0, 0.0, 99.15, 0, 'LegendNANA'],
#  ['2020-01-19T12:00', -0.9, -3.2, 85.0, 0.0, 99.26, 0, 'LegendNANA'],
#  ['2020-01-19T13:00', -1.0, -5.1, 74.0, 0.0, 99.38, 0, 'LegendNANA'],
#  ['2020-01-19T14:00', -2.6, -7.0, 72.0, 0.0, 99.51, 0, 'LegendNANA'],
#  ['2020-01-19T15:00', -3.7, -9.5, 64.0, 0.0, 99.61, 0, 'LegendNANA'],
#  ['2020-01-19T16:00', -5.2, -10.2, 68.0, 0.0, 99.8, 0, 'LegendNANA'],
#  ['2020-01-19T17:00', -6.5, -11.6, 67.0, 0.0, 99.86, 0, 'LegendNANA'],
#  ['2020-01-19T18:00', -6.4, -12.5, 62.0, 0.0, 99.95, 0, 'LegendNANA'],
#  ['2020-01-19T19:00', -6.4, -12.3, 63.0, 0.0, 100.01, 0, 'LegendNANA'],
#  ['2020-01-19T20:00', -5.8, -12.0, 62.0, 0.0, 100.12, 0, 'LegendNANA'],
#  ['2020-01-19T21:00', -6.7, -12.1, 66.0, 0.0, 100.29, 0, 'LegendNANA'],
#  ['2020-01-19T22:00', -7.7, -13.0, 65.0, 0.0, 100.45, 0, 'LegendNANA'],
#  ['2020-01-19T23:00', -8.1, -13.6, 65.0, 0.0, 100.61, 0, 'LegendNANA'],
#  ['2020-01-20T00:00', -8.0, -13.7, 63.0, 0.0, 100.73, 0, 'LegendNANA'],
#  ['2020-01-20T01:00', -7.7, -13.6, 62.0, 0.0, 100.82, 0, 'LegendNANA'],
#  ['2020-01-20T02:00', -7.6, -13.5, 63.0, 0.0, 100.9, 0, 'LegendNANA'],
#  ['2020-01-20T03:00', -7.9, -14.2, 61.0, 0.0, 101.0, 0, 'LegendNANA'],
#  ['2020-01-20T04:00', -9.0, -15.9, 57.0, 0.0, 101.09, 0, 'LegendNANA'],
#  ['2020-01-20T05:00', -9.6, -16.8, 56.0, 0.0, 101.14, 0, 'LegendNANA'],
#  ['2020-01-20T06:00', -10.4, -16.5, 61.0, 0.0, 101.18, 0, 'LegendNANA'],
#  ['2020-01-20T07:00', -10.8, -16.7, 61.0, 0.0, 101.22, 0, 'LegendNANA'],
#  ['2020-01-20T08:00', -11.4, -16.8, 65.0, 0.0, 101.27, 0, 'LegendNANA'],
#  ['2020-01-20T09:00', -12.2, -17.1, 67.0, 0.0, 101.37, 0, 'LegendNANA'],
#  ['2020-01-20T10:00', -12.5, -17.2, 68.0, 0.0, 101.43, 0, 'LegendNANA'],
#  ['2020-01-20T11:00', -12.7, -17.4, 68.0, 0.2, 101.53, 0, 'LegendNANA'],
#  ['2020-01-20T12:00', -13.0, -17.9, 67.0, 0.0, 101.63, 0, 'LegendNANA'],
#  ['2020-01-20T13:00', -12.8, -17.8, 66.0, 0.0, 101.67, 0, 'LegendNANA'],
#  ['2020-01-20T14:00', -11.6, -16.7, 66.0, 0.0, 101.77, 0, 'LegendNANA'],
#  ['2020-01-20T15:00', -9.7, -15.4, 63.0, 0.0, 101.84, 0, 'LegendNANA'],
#  ['2020-01-20T16:00', -8.4, -15.8, 55.0, 0.0, 101.86, 0, 'LegendNANA'],
#  ['2020-01-20T17:00', -7.5, -14.0, 60.0, 0.0, 101.84, 0, 'LegendNANA'],
#  ['2020-01-20T18:00', -6.4, -14.0, 55.0, 0.0, 101.8, 0, 'LegendNANA'],
#  ['2020-01-20T19:00', -5.8, -13.9, 53.0, 0.4, 101.74, 0, 'LegendNANA'],
#  ['2020-01-20T20:00', -5.7, -12.3, 60.0, 0.0, 101.72, 0, 'LegendNANA'],
#  ['2020-01-20T21:00', -4.7, -14.4, 47.0, 0.0, 101.72, 0, 'LegendNANA'],
#  ['2020-01-20T22:00', -4.9, -12.7, 54.0, 0.0, 101.71, 0, 'LegendNANA'],
#  ['2020-01-20T23:00', -4.8, -11.3, 60.0, 0.0, 101.75, 0, 'LegendNANA'],
#  ['2020-01-21T00:00', -5.2, -10.6, 65.0, 0.0, 101.76, 0, 'LegendNANA'],
#  ['2020-01-21T01:00', -5.7, -10.6, 68.0, 0.0, 101.73, 0, 'LegendNANA'],
#  ['2020-01-21T02:00', -6.1, -10.4, 72.0, 0.0, 101.73, 0, 'LegendNANA'],
#  ['2020-01-21T03:00', -6.5, -10.3, 74.0, 0.0, 101.74, 0, 'LegendNANA'],
#  ['2020-01-21T04:00', -6.8, -10.2, 77.0, 0.0, 101.77, 0, 'LegendNANA'],
#  ['2020-01-21T05:00', -7.6, -10.6, 79.0, 0.0, 101.8, 0, 'LegendNANA'],
#  ['2020-01-21T06:00', -7.4, -9.7, 83.0, 0.0, 101.77, 0, 'LegendNANA'],
#  ['2020-01-21T07:00', -6.3, -9.8, 76.0, 0.0, 101.78, 0, 'LegendNANA'],
#  ['2020-01-21T08:00', -6.1, -9.5, 77.0, 0.0, 101.79, 0, 'LegendNANA'],
#  ['2020-01-21T09:00', -5.7, -9.2, 76.0, 0.0, 101.77, 0, 'LegendNANA'],
#  ['2020-01-21T10:00', -6.1, -9.6, 77.0, 0.0, 101.78, 0, 'LegendNANA'],
#  ['2020-01-21T11:00', -6.5, -10.1, 76.0, 0.0, 101.78, 0, 'LegendNANA'],
#  ['2020-01-21T12:00', -5.2, -8.9, 75.0, 0.0, 101.81, 0, 'LegendNANA'],
#  ['2020-01-21T13:00', -4.2, -8.4, 73.0, 0.0, 101.82, 0, 'LegendNANA'],
#  ['2020-01-21T14:00', -3.7, -7.9, 73.0, 0.0, 101.81, 0, 'LegendNANA'],
#  ['2020-01-21T15:00', -3.1, -7.4, 72.0, 0.0, 101.81, 0, 'LegendNANA'],
#  ['2020-01-21T16:00', -2.4, -7.5, 68.0, 0.0, 101.81, 0, 'LegendNANA'],
#  ['2020-01-21T17:00', -2.0, -8.2, 63.0, 0.0, 101.76, 0, 'LegendNANA'],
#  ['2020-01-21T18:00', -2.2, -8.4, 63.0, 0.0, 101.73, 0, 'LegendNANA'],
#  ['2020-01-21T19:00', -1.9, -8.5, 61.0, 0.0, 101.66, 0, 'LegendNANA'],
#  ['2020-01-21T20:00', -1.9, -8.7, 60.0, 0.0, 101.68, 0, 'LegendNANA'],
#  ['2020-01-21T21:00', -2.6, -8.8, 62.0, 0.0, 101.65, 0, 'LegendNANA'],
#  ['2020-01-21T22:00', -2.9, -8.9, 64.0, 0.0, 101.65, 0, 'LegendNANA'],
#  ['2020-01-21T23:00', -3.5, -9.2, 65.0, 0.0, 101.63, 0, 'LegendNANA'],
#  ['2020-01-22T00:00', -4.1, -9.5, 66.0, 0.0, 101.62, 0, 'LegendNANA'],
#  ['2020-01-22T01:00', -4.7, -10.1, 66.0, 0.0, 101.63, 0, 'LegendNANA'],
#  ['2020-01-22T02:00', -5.2, -10.5, 66.0, 0.0, 101.62, 0, 'LegendNANA'],
#  ['2020-01-22T03:00', -4.9, -10.1, 67.0, 0.0, 101.56, 0, 'LegendNANA'],
#  ['2020-01-22T04:00', -5.1, -10.0, 69.0, 0.0, 101.47, 0, 'LegendNANA'],
#  ['2020-01-22T05:00', -5.2, -10.1, 68.0, 0.0, 101.44, 0, 'LegendNANA'],
#  ['2020-01-22T06:00', -5.2, -9.9, 70.0, 0.0, 101.4, 0, 'LegendNANA'],
#  ['2020-01-22T07:00', -5.0, -9.7, 70.0, 0.0, 101.43, 0, 'LegendNANA'],
#  ['2020-01-22T08:00', -5.1, -9.3, 72.0, 0.0, 101.43, 0, 'LegendNANA'],
#  ['2020-01-22T09:00', -4.6, -8.8, 72.0, 0.0, 101.38, 0, 'LegendNANA'],
#  ['2020-01-22T10:00', -4.3, -8.5, 73.0, 0.0, 101.35, 0, 'LegendNANA'],
#  ['2020-01-22T11:00', -4.6, -8.3, 75.0, 0.0, 101.29, 0, 'LegendNANA'],
#  ['2020-01-22T12:00', -4.3, -7.9, 76.0, 0.0, 101.34, 0, 'LegendNANA'],
#  ['2020-01-22T13:00', -3.9, -7.4, 77.0, 0.0, 101.33, 0, 'LegendNANA'],
#  ['2020-01-22T14:00', -2.8, -6.2, 77.0, 0.0, 101.38, 0, 'LegendNANA'],
#  ['2020-01-22T15:00', -1.4, -6.0, 71.0, 0.0, 101.36, 0, 'LegendNANA'],
#  ['2020-01-22T16:00', -0.7, -5.7, 69.0, 0.0, 101.37, 0, 'LegendNANA'],
#  ['2020-01-22T17:00', 0.4, -5.4, 65.0, 0.0, 101.28, 0, 'LegendNANA'],
#  ['2020-01-22T18:00', 0.4, -5.1, 66.0, 0.0, 101.21, 0, 'LegendNANA'],
#  ['2020-01-22T19:00', 0.5, -4.2, 70.0, 0.0, 101.17, 0, 'LegendNANA'],
#  ['2020-01-22T20:00', 1.2, -3.7, 70.0, 0.0, 101.15, 0, 'LegendNANA'],
#  ['2020-01-22T21:00', 0.5, -3.8, 73.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-01-22T22:00', 0.5, -5.2, 66.0, 0.0, 101.17, 0, 'LegendNANA'],
#  ['2020-01-22T23:00', 0.0, -5.6, 66.0, 0.0, 101.17, 0, 'LegendNANA'],
#  ['2020-01-23T00:00', -0.4, -5.8, 67.0, 0.0, 101.19, 0, 'LegendNANA'],
#  ['2020-01-23T01:00', -0.7, -5.7, 69.0, 0.0, 101.23, 0, 'LegendNANA'],
#  ['2020-01-23T02:00', -0.9, -5.8, 69.0, 0.0, 101.2, 0, 'LegendNANA'],
#  ['2020-01-23T03:00', -1.2, -6.3, 68.0, 0.0, 101.17, 0, 'LegendNANA'],
#  ['2020-01-23T04:00', -1.2, -6.6, 67.0, 0.0, 101.17, 0, 'LegendNANA'],
#  ['2020-01-23T05:00', -2.0, -7.1, 68.0, 0.0, 101.15, 0, 'LegendNANA'],
#  ['2020-01-23T06:00', -1.9, -7.3, 66.0, 0.0, 101.14, 0, 'LegendNANA'],
#  ['2020-01-23T07:00', -1.6, -6.9, 67.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-01-23T08:00', -2.2, -7.2, 68.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-01-23T09:00', -1.6, -6.8, 67.0, 0.0, 101.1, 0, 'LegendNANA'],
#  ['2020-01-23T10:00', -1.7, -6.5, 70.0, 0.0, 101.07, 0, 'LegendNANA'],
#  ['2020-01-23T11:00', -1.3, -6.3, 69.0, 0.0, 101.1, 0, 'LegendNANA'],
#  ['2020-01-23T12:00', -1.4, -6.2, 70.0, 0.0, 101.09, 0, 'LegendNANA'],
#  ['2020-01-23T13:00', -0.8, -5.6, 70.0, 0.0, 101.13, 0, 'LegendNANA'],
#  ['2020-01-23T14:00', -0.4, -5.8, 67.0, 0.0, 101.18, 0, 'LegendNANA'],
#  ['2020-01-23T15:00', 0.8, -5.5, 63.0, 0.0, 101.21, 0, 'LegendNANA'],
#  ['2020-01-23T16:00', 2.0, -5.3, 58.0, 0.0, 101.21, 0, 'LegendNANA'],
#  ['2020-01-23T17:00', 2.4, -5.4, 56.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-01-23T18:00', 3.0, -5.6, 53.0, 0.3, 101.09, 0, 'LegendNANA'],
#  ['2020-01-23T19:00', 3.3, -4.7, 56.0, 0.2, 101.01, 0.0, 'LegendNANA'],
#  ['2020-01-23T20:00', 3.1, -3.8, 61.0, 0.0, 101.04, 0.0, 'LegendNANA'],
#  ['2020-01-23T21:00', 2.7, -2.8, 67.0, 0.0, 101.08, 0, 'LegendNANA'],
#  ['2020-01-23T22:00', 2.4, -1.8, 74.0, 0.0, 101.09, 0, 'LegendNANA'],
#  ['2020-01-23T23:00', 2.3, -1.6, 75.0, 0.0, 101.11, 0, 'LegendNANA'],
#  ['2020-01-24T00:00', 2.2, -1.9, 74.0, 0.0, 101.09, 0, 'LegendNANA'],
#  ['2020-01-24T01:00', 2.3, -2.3, 72.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-01-24T02:00', 2.3, -2.3, 72.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-01-24T03:00', 2.0, -1.6, 77.0, 0.0, 101.13, 0, 'LegendNANA'],
#  ['2020-01-24T04:00', 1.8, -1.5, 79.0, 0.0, 101.12, 0, 'LegendNANA'],
#  ['2020-01-24T05:00', 1.6, -1.8, 78.0, 0.0, 101.11, 0, 'LegendNANA'],
#  ['2020-01-24T06:00', 1.5, -1.9, 78.0, 0.0, 101.06, 0, 'LegendNANA'],
#  ['2020-01-24T07:00', 1.5, -2.4, 75.0, 0.0, 101.05, 0, 'LegendNANA'],
#  ['2020-01-24T08:00', 1.5, -3.7, 68.0, 0.0, 101.02, 0, 'LegendNANA'],
#  ['2020-01-24T09:00', 1.4, -3.8, 68.0, 0.0, 101.02, 0, 'LegendNANA'],
#  ['2020-01-24T10:00', 1.5, -3.3, 70.0, 0.0, 100.97, 0, 'LegendNANA'],
#  ['2020-01-24T11:00', 1.7, -4.2, 65.0, 0.0, 101.0, 0, 'LegendNANA'],
#  ['2020-01-24T12:00', 1.8, -4.5, 63.0, 0.0, 100.99, 0, 'LegendNANA'],
#  ['2020-01-24T13:00', 1.6, -4.7, 63.0, 0.0, 100.99, 0, 'LegendNANA'],
#  ['2020-01-24T14:00', 1.8, -4.6, 62.0, 0.0, 101.01, 0, 'LegendNANA'],
#  ['2020-01-24T15:00', 2.3, -4.6, 60.0, 0.0, 100.95, 0, 'LegendNANA'],
#  ['2020-01-24T16:00', 2.7, -4.9, 57.0, 0.0, 100.93, 0, 'LegendNANA'],
#  ['2020-01-24T17:00', 3.3, -4.4, 57.0, 0.0, 100.86, 0.0, 'LegendNANA'],
#  ['2020-01-24T18:00', 2.9, -3.6, 62.0, 0.0, 100.71, 0, 'LegendNANA'],
#  ['2020-01-24T19:00', 2.8, -3.6, 63.0, 0.0, 100.68, 0, 'LegendNANA'],
#  ['2020-01-24T20:00', 2.9, -2.9, 65.0, 0.0, 100.65, 0.0, 'LegendNANA'],
#  ['2020-01-24T21:00', 3.0, -2.8, 66.0, 0.0, 100.63, 0.0, 'LegendNANA'],
#  ['2020-01-24T22:00', 3.1, -2.7, 66.0, 0.0, 100.58, 0.0, 'LegendNANA'],
#  ['2020-01-24T23:00', 3.1, -2.4, 67.0, 0.0, 100.52, 0.0, 'LegendNANA'],
#  ['2020-01-25T00:00', 3.3, -1.2, 73.0, 0.0, 100.43, 1.0, 'LegendNANA'],
#  ['2020-01-25T01:00', 3.2, 0.7, 84.0, 2.8, 100.39, 1.0, 'LegendNANA'],
#  ['2020-01-25T02:00', 3.4, 1.8, 89.0, 5.8, 100.3, 2.0, 'LegendNANA'],
#  ['2020-01-25T03:00', 3.4, 1.7, 88.0, 3.2, 100.31, 2.0, 'LegendNANA'],
#  ['2020-01-25T04:00', 3.3, 1.3, 87.0, 2.0, 100.25, 1.0, 'LegendNANA'],
#  ['2020-01-25T05:00', 3.2, 1.2, 86.0, 5.3, 100.19, 1.0, 'LegendNANA'],
#  ['2020-01-25T06:00', 3.5, 1.9, 89.0, 1.8, 100.14, 2.0, 'LegendNANA'],
#  ['2020-01-25T07:00', 3.7, 2.3, 91.0, 2.1, 100.08, 2.0, 'LegendNANA'],
#  ['2020-01-25T08:00', 3.8, 2.5, 91.0, 0.5, 100.06, 2.0, 'LegendNANA'],
#  ['2020-01-25T09:00', 3.8, 2.3, 90.0, 0.9, 100.03, 2.0, 'LegendNANA'],
#  ['2020-01-25T10:00', 3.4, 1.8, 89.0, 1.5, 99.93, 2.0, 'LegendNANA'],
#  ['2020-01-25T11:00', 3.2, 1.1, 86.0, 0.2, 99.87, 1.0, 'LegendNANA'],
#  ['2020-01-25T12:00', 3.1, 0.9, 86.0, 0.2, 99.89, 1.0, 'LegendNANA'],
#  ['2020-01-25T13:00', 2.9, 0.5, 84.0, 0.8, 99.85, 1.0, 'LegendNANA'],
#  ['2020-01-25T14:00', 2.8, 0.6, 85.0, 0.2, 99.82, 1.0, 'LegendNANA'],
#  ['2020-01-25T15:00', 2.6, 1.0, 89.0, 0.3, 99.82, 1.0, 'LegendNANA'],
#  ['2020-01-25T16:00', 2.6, 1.3, 91.0, 0.3, 99.77, 1.0, 'LegendNANA'],
#  ['2020-01-25T17:00', 2.9, 1.6, 92.0, 0.3, 99.72, 1.0, 'LegendNANA'],
#  ['2020-01-25T18:00', 3.0, 1.9, 93.0, 0.2, 99.6, 1.0, 'LegendNANA'],
#  ['2020-01-25T19:00', 3.1, 2.0, 93.0, 0.2, 99.53, 1.0, 'LegendNANA'],
#  ['2020-01-25T20:00', 3.1, 2.2, 93.0, 0.0, 99.51, 2.0, 'LegendNANA'],
#  ['2020-01-25T21:00', 3.4, 2.4, 93.0, 0.0, 99.51, 2.0, 'LegendNANA'],
#  ['2020-01-25T22:00', 3.4, 2.4, 93.0, 0.2, 99.52, 2.0, 'LegendNANA'],
#  ['2020-01-25T23:00', 3.3, 2.0, 91.0, 0.0, 99.52, 2.0, 'LegendNANA'],
#  ['2020-01-26T00:00', 3.3, 1.7, 89.0, 0.0, 99.52, 2.0, 'LegendNANA'],
#  ['2020-01-26T01:00', 3.1, 1.3, 88.0, 0.0, 99.53, 1.0, 'LegendNANA'],
#  ['2020-01-26T02:00', 2.8, 0.9, 88.0, 0.0, 99.47, 1.0, 'LegendNANA'],
#  ['2020-01-26T03:00', 2.9, 0.7, 86.0, 0.0, 99.43, 1.0, 'LegendNANA'],
#  ['2020-01-26T04:00', 2.8, 0.3, 84.0, 0.0, 99.4, 1.0, 'LegendNANA'],
#  ['2020-01-26T05:00', 2.1, 0.1, 86.0, 0.0, 99.38, 0, 'LegendNANA'],
#  ['2020-01-26T06:00', 2.2, 0.0, 85.0, 0.0, 99.35, 0.0, 'LegendNANA'],
#  ['2020-01-26T07:00', 2.1, 0.1, 87.0, 0.0, 99.31, 0, 'LegendNANA'],
#  ['2020-01-26T08:00', 2.1, -0.5, 83.0, 0.0, 99.32, 0, 'LegendNANA'],
#  ['2020-01-26T09:00', 2.0, -0.6, 83.0, 0.0, 99.29, 0, 'LegendNANA'],
#  ['2020-01-26T10:00', 1.8, -0.5, 84.0, 0.0, 99.28, 0, 'LegendNANA'],
#  ['2020-01-26T11:00', 1.8, -0.3, 86.0, 0.0, 99.25, 0, 'LegendNANA'],
#  ['2020-01-26T12:00', 1.9, -0.3, 85.0, 0.0, 99.23, 0, 'LegendNANA'],
#  ['2020-01-26T13:00', 2.3, -0.2, 84.0, 0.0, 99.24, 0.0, 'LegendNANA'],
#  ['2020-01-26T14:00', 2.4, -0.2, 83.0, 0.0, 99.24, 0.0, 'LegendNANA'],
#  ['2020-01-26T15:00', 2.6, -0.1, 82.0, 0.0, 99.24, 0.0, 'LegendNANA'],
#  ['2020-01-26T16:00', 3.4, -0.1, 78.0, 0.0, 99.28, 1.0, 'LegendNANA'],
#  ['2020-01-26T17:00', 3.7, -0.5, 74.0, 0.0, 99.24, 1.0, 'LegendNANA'],
#  ['2020-01-26T18:00', 4.0, -0.5, 72.0, 0.0, 99.17, 2.0, 'LegendNANA'],
#  ['2020-01-26T19:00', 3.9, -0.4, 73.0, 0.0, 99.13, 2.0, 'LegendNANA'],
#  ['2020-01-26T20:00', 3.8, -0.5, 74.0, 0.0, 99.09, 2.0, 'LegendNANA'],
#  ['2020-01-26T21:00', 3.0, 0.3, 82.0, 0.0, 99.09, 1.0, 'LegendNANA'],
#  ['2020-01-26T22:00', 2.5, 0.7, 88.0, 0.6, 99.08, 1.0, 'LegendNANA'],
#  ['2020-01-26T23:00', 2.5, 0.6, 87.0, 0.3, 99.08, 0.0, 'LegendNANA'],
#  ['2020-01-27T00:00', 2.3, 0.5, 88.0, 0.0, 99.08, 0.0, 'LegendNANA'],
#  ['2020-01-27T01:00', 2.1, 0.2, 87.0, 0.0, 99.08, 0, 'LegendNANA'],
#  ['2020-01-27T02:00', 1.9, -0.2, 86.0, 0.2, 99.07, 0, 'LegendNANA'],
#  ['2020-01-27T03:00', 1.7, -0.4, 86.0, 0.2, 99.06, 0, 'LegendNANA'],
#  ['2020-01-27T04:00', 1.6, -0.7, 85.0, 0.0, 99.04, 0, 'LegendNANA'],
#  ['2020-01-27T05:00', 1.7, -1.4, 80.0, 0.0, 99.03, 0, 'LegendNANA'],
#  ['2020-01-27T06:00', 1.9, -1.5, 78.0, 0.0, 99.01, 0, 'LegendNANA'],
#  ['2020-01-27T07:00', 2.0, -1.5, 77.0, 0.0, 99.03, 0, 'LegendNANA'],
#  ['2020-01-27T08:00', 2.1, -1.4, 77.0, 0.0, 99.07, 0, 'LegendNANA'],
#  ['2020-01-27T09:00', 1.9, -1.4, 78.0, 0.0, 99.06, 0, 'LegendNANA'],
#  ['2020-01-27T10:00', 1.9, -1.4, 78.0, 0.0, 99.1, 0, 'LegendNANA'],
#  ['2020-01-27T11:00', 1.9, -1.6, 77.0, 0.0, 99.13, 0, 'LegendNANA'],
#  ['2020-01-27T12:00', 1.6, -1.5, 80.0, 0.0, 99.2, 0, 'LegendNANA'],
#  ['2020-01-27T13:00', 1.4, -1.8, 79.0, 0.0, 99.27, 0, 'LegendNANA'],
#  ['2020-01-27T14:00', 1.3, -1.8, 80.0, 0.0, 99.33, 0, 'LegendNANA'],
#  ['2020-01-27T15:00', 1.6, -2.9, 72.0, 0.0, 99.37, 0, 'LegendNANA'],
#  ['2020-01-27T16:00', 1.1, -3.1, 74.0, 0.0, 99.43, 0, 'LegendNANA'],
#  ['2020-01-27T17:00', 1.2, -3.4, 71.0, 0.0, 99.43, 0, 'LegendNANA'],
#  ['2020-01-27T18:00', 1.7, -2.6, 73.0, 0.0, 99.41, 0, 'LegendNANA'],
#  ['2020-01-27T19:00', 2.0, -3.7, 66.0, 0.0, 99.38, 0, 'LegendNANA'],
#  ['2020-01-27T20:00', 1.9, -3.4, 68.0, 0.0, 99.44, 0, 'LegendNANA'],
#  ['2020-01-27T21:00', 1.6, -3.2, 71.0, 0.0, 99.49, 0, 'LegendNANA'],
#  ['2020-01-27T22:00', 1.4, -3.4, 70.0, 0.0, 99.54, 0, 'LegendNANA'],
#  ['2020-01-27T23:00', 1.1, -3.4, 72.0, 0.0, 99.59, 0, 'LegendNANA'],
#  ['2020-01-28T00:00', 1.0, -3.3, 73.0, 0.0, 99.65, 0, 'LegendNANA'],
#  ['2020-01-28T01:00', 0.9, -3.1, 74.0, 0.0, 99.69, 0, 'LegendNANA'],
#  ['2020-01-28T02:00', 0.9, -2.9, 76.0, 0.0, 99.7, 0, 'LegendNANA'],
#  ['2020-01-28T03:00', 1.2, -2.8, 75.0, 0.0, 99.72, 0, 'LegendNANA'],
#  ['2020-01-28T04:00', 1.1, -2.8, 75.0, 0.0, 99.72, 0, 'LegendNANA'],
#  ['2020-01-28T05:00', 1.1, -2.8, 75.0, 0.0, 99.76, 0, 'LegendNANA'],
#  ['2020-01-28T06:00', 1.1, -2.9, 74.0, 0.0, 99.76, 0, 'LegendNANA'],
#  ['2020-01-28T07:00', 1.1, -3.1, 74.0, 0.0, 99.78, 0, 'LegendNANA'],
#  ['2020-01-28T08:00', 0.8, -3.2, 74.0, 0.0, 99.81, 0, 'LegendNANA'],
#  ['2020-01-28T09:00', 0.3, -1.8, 86.0, 0.2, 99.82, 0, 'LegendNANA'],
#  ['2020-01-28T10:00', 0.1, -1.9, 86.0, 0.0, 99.85, 0, 'LegendNANA'],
#  ['2020-01-28T11:00', 0.0, -2.2, 85.0, 0.0, 99.88, 0, 'LegendNANA'],
#  ['2020-01-28T12:00', 0.4, -3.7, 74.0, 0.0, 99.92, 0, 'LegendNANA'],
#  ['2020-01-28T13:00', 0.5, -4.1, 71.0, 0.0, 99.96, 0, 'LegendNANA'],
#  ['2020-01-28T14:00', 0.3, -4.7, 69.0, 0.0, 100.02, 0, 'LegendNANA'],
#  ['2020-01-28T15:00', 0.8, -4.1, 69.0, 0.0, 100.04, 0, 'LegendNANA'],
#  ['2020-01-28T16:00', 0.9, -3.9, 70.0, 0.0, 100.07, 0, 'LegendNANA'],
#  ['2020-01-28T17:00', 1.4, -3.7, 68.0, 0.0, 100.03, 0, 'LegendNANA'],
#  ['2020-01-28T18:00', 1.6, -4.0, 66.0, 0.0, 99.99, 0, 'LegendNANA'],
#  ['2020-01-28T19:00', 1.9, -4.4, 63.0, 0.0, 99.97, 0, 'LegendNANA'],
#  ['2020-01-28T20:00', 2.1, -4.8, 60.0, 0.0, 100.02, 0, 'LegendNANA'],
#  ['2020-01-28T21:00', 1.8, -6.2, 55.0, 0.2, 100.05, 0, 'LegendNANA'],
#  ['2020-01-28T22:00', 1.0, -4.1, 69.0, 0.0, 100.11, 0, 'LegendNANA'],
#  ['2020-01-28T23:00', 0.8, -3.9, 71.0, 0.0, 100.19, 0, 'LegendNANA'],
#  ['2020-01-29T00:00', 0.3, -4.5, 70.0, 0.0, 100.26, 0, 'LegendNANA'],
#  ['2020-01-29T01:00', 0.2, -4.0, 74.0, 0.0, 100.31, 0, 'LegendNANA'],
#  ['2020-01-29T02:00', -0.1, -3.8, 76.0, 0.0, 100.37, 0, 'LegendNANA'],
#  ['2020-01-29T03:00', -0.5, -5.6, 68.0, 0.0, 100.4, 0, 'LegendNANA'],
#  ['2020-01-29T04:00', -0.6, -5.2, 71.0, 0.0, 100.43, 0, 'LegendNANA'],
#  ['2020-01-29T05:00', -0.7, -5.3, 71.0, 0.0, 100.49, 0, 'LegendNANA'],
#  ['2020-01-29T06:00', -1.1, -5.8, 70.0, 0.0, 100.52, 0, 'LegendNANA'],
#  ['2020-01-29T07:00', -1.5, -6.4, 69.0, 0.0, 100.58, 0, 'LegendNANA'],
#  ['2020-01-29T08:00', -3.1, -7.5, 71.0, 0.0, 100.63, 0, 'LegendNANA'],
# ...
#  ['2020-02-02T05:00', 0.2, -1.8, 87.0, 0.0, 99.0, 0, 'LegendNANA'],
#  ['2020-02-02T06:00', 0.3, -1.8, 86.0, 0.2, 98.92, 0, 'LegendNANA'],
#  ['2020-02-02T07:00', 0.3, -1.6, 87.0, 0.0, 98.86, 0, 'LegendNANA'],
#  ['2020-02-02T08:00', 0.2, -1.7, 87.0, 0.0, 98.82, 0, 'LegendNANA'],
#  ['2020-02-02T09:00', 0.4, -1.6, 87.0, 0.0, 98.79, 0, 'LegendNANA'],
#  ['2020-02-02T10:00', 0.9, -1.4, 85.0, 0.0, 98.74, 0, 'LegendNANA'],
#  ['2020-02-02T11:00', 0.2, -2.6, 82.0, 0.0, 98.72, 0, 'LegendNANA'],
#  ['2020-02-02T12:00', 0.4, -2.8, 79.0, 0.0, 98.7, 0, 'LegendNANA'],
#  ['2020-02-02T13:00', 0.6, -2.3, 81.0, 0.0, 98.62, 0, 'LegendNANA'],
#  ['2020-02-02T14:00', 0.2, -1.6, 87.0, 0.3, 98.6, 0, 'LegendNANA'],
#  ['2020-02-02T15:00', 0.5, -0.8, 91.0, 0.5, 98.49, 0, 'LegendNANA'],
#  ['2020-02-02T16:00', 0.6, -0.5, 92.0, 1.5, 98.4, 0, 'LegendNANA'],
#  ['2020-02-02T17:00', 0.7, -0.3, 92.0, 0.8, 98.27, 0, 'LegendNANA'],
#  ['2020-02-02T18:00', 0.8, -0.3, 92.0, 1.1, 98.14, 0, 'LegendNANA'],
#  ['2020-02-02T19:00', 1.2, 0.0, 92.0, 0.5, 98.08, 0, 'LegendNANA'],
#  ['2020-02-02T20:00', 1.4, 0.1, 91.0, 0.5, 98.06, 0, 'LegendNANA'],
#  ['2020-02-02T21:00', 1.6, 0.2, 90.0, 0.2, 98.12, 0, 'LegendNANA'],
#  ['2020-02-02T22:00', 1.7, 0.2, 90.0, 0.0, 98.2, 0, 'LegendNANA'],
#  ['2020-02-02T23:00', 1.7, 0.3, 90.0, 0.0, 98.26, 0, 'LegendNANA'],
#  ['2020-02-03T00:00', 1.7, 0.3, 90.0, 0.2, 98.37, 0, 'LegendNANA'],
#  ['2020-02-03T01:00', 1.6, 0.2, 90.0, 0.2, 98.42, 0, 'LegendNANA'],
#  ['2020-02-03T02:00', 1.5, 0.3, 91.0, 0.2, 98.45, 0, 'LegendNANA'],
#  ['2020-02-03T03:00', 1.8, 0.4, 91.0, 0.0, 98.57, 0, 'LegendNANA'],
#  ['2020-02-03T04:00', 1.9, 0.6, 91.0, 0.0, 98.64, 0, 'LegendNANA'],
#  ['2020-02-03T05:00', 2.3, 0.7, 90.0, 0.0, 98.7, 0.0, 'LegendNANA'],
#  ['2020-02-03T06:00', 2.3, 0.8, 90.0, 0.0, 98.78, 0.0, 'LegendNANA'],
#  ['2020-02-03T07:00', 2.7, 1.0, 88.0, 0.0, 98.87, 1.0, 'LegendNANA'],
#  ['2020-02-03T08:00', 3.1, 0.2, 82.0, 0.0, 98.98, 1.0, 'LegendNANA'],
#  ['2020-02-03T09:00', 3.3, -0.4, 77.0, 0.0, 99.11, 1.0, 'LegendNANA'],
#  ['2020-02-03T10:00', 3.6, -1.0, 72.0, 0.0, 99.26, 1.0, 'LegendNANA'],
#  ['2020-02-03T11:00', 3.5, -1.7, 69.0, 0.2, 99.35, 1.0, 'LegendNANA'],
#  ['2020-02-03T12:00', 3.5, -1.6, 69.0, 0.0, 99.46, 1.0, 'LegendNANA'],
#  ['2020-02-03T13:00', 3.4, -1.8, 69.0, 0.0, 99.56, 1.0, 'LegendNANA'],
#  ['2020-02-03T14:00', 3.7, -1.9, 67.0, 0.0, 99.63, 1.0, 'LegendNANA'],
#  ['2020-02-03T15:00', 4.1, -2.4, 63.0, 0.0, 99.61, 1.0, 'LegendNANA'],
#  ['2020-02-03T16:00', 4.4, -2.4, 61.0, 0.0, 99.72, 2.0, 'LegendNANA'],
#  ['2020-02-03T17:00', 4.9, -2.7, 58.0, 0.0, 99.71, 2.0, 'LegendNANA'],
#  ['2020-02-03T18:00', 5.6, -3.4, 52.0, 0.0, 99.64, 3.0, 'LegendNANA'],
#  ['2020-02-03T19:00', 5.3, -2.6, 57.0, 0.3, 99.62, 3.0, 'LegendNANA'],
#  ['2020-02-03T20:00', 5.4, -3.0, 55.0, 0.0, 99.62, 3.0, 'LegendNANA'],
#  ['2020-02-03T21:00', 5.4, -2.9, 55.0, 0.0, 99.64, 3.0, 'LegendNANA'],
#  ['2020-02-03T22:00', 4.9, -4.2, 52.0, 0.0, 99.65, 2.0, 'LegendNANA'],
#  ['2020-02-03T23:00', 4.5, -3.7, 55.0, 0.0, 99.67, 2.0, 'LegendNANA'],
#  ['2020-02-04T00:00', 3.5, -3.3, 61.0, 0.0, 99.72, 1.0, 'LegendNANA'],
#  ['2020-02-04T01:00', 3.9, -3.1, 60.0, 0.0, 99.69, 1.0, 'LegendNANA'],
#  ['2020-02-04T02:00', 2.7, -3.3, 64.0, 0.0, 99.62, 0, 'LegendNANA'],
#  ['2020-02-04T03:00', 2.4, -3.6, 64.0, 0.0, 99.53, 0, 'LegendNANA'],
#  ['2020-02-04T04:00', 2.6, -3.7, 63.0, 0.0, 99.51, 0, 'LegendNANA'],
#  ['2020-02-04T05:00', 2.8, -3.9, 62.0, 0.0, 99.49, 0, 'LegendNANA'],
#  ['2020-02-04T06:00', 2.8, -4.4, 59.0, 0.0, 99.4, 0, 'LegendNANA'],
#  ['2020-02-04T07:00', 2.7, -4.4, 60.0, 0.0, 99.43, 0, 'LegendNANA'],
#  ['2020-02-04T08:00', 2.7, -4.4, 59.0, 0.0, 99.39, 0, 'LegendNANA'],
#  ['2020-02-04T09:00', 2.4, -4.0, 63.0, 0.0, 99.36, 0, 'LegendNANA'],
#  ['2020-02-04T10:00', 2.6, -4.2, 61.0, 0.0, 99.44, 0, 'LegendNANA'],
#  ['2020-02-04T11:00', 2.1, -4.1, 63.0, 0.0, 99.5, 0, 'LegendNANA'],
#  ['2020-02-04T12:00', 2.1, -4.2, 63.0, 0.0, 99.59, 0, 'LegendNANA'],
#  ['2020-02-04T13:00', 2.0, -5.2, 59.0, 0.0, 99.68, 0, 'LegendNANA'],
#  ['2020-02-04T14:00', 1.9, -5.1, 60.0, 0.0, 99.73, 0, 'LegendNANA'],
#  ['2020-02-04T15:00', 2.3, -4.7, 60.0, 0.0, 99.8, 0, 'LegendNANA'],
#  ['2020-02-04T16:00', 2.7, -4.1, 61.0, 0.0, 99.84, 0, 'LegendNANA'],
#  ['2020-02-04T17:00', 2.9, -3.2, 64.0, 0.0, 99.8, 0.0, 'LegendNANA'],
#  ['2020-02-04T18:00', 2.9, -2.9, 65.0, 0.0, 99.81, 0.0, 'LegendNANA'],
#  ['2020-02-04T19:00', 2.6, -5.2, 56.0, 0.0, 99.79, 0, 'LegendNANA'],
#  ['2020-02-04T20:00', 2.2, -5.5, 57.0, 0.0, 99.84, 0, 'LegendNANA'],
#  ['2020-02-04T21:00', 2.1, -5.3, 58.0, 0.0, 99.9, 0, 'LegendNANA'],
#  ['2020-02-04T22:00', 1.7, -6.0, 56.0, 0.0, 99.94, 0, 'LegendNANA'],
#  ['2020-02-04T23:00', 1.4, -5.8, 59.0, 0.0, 100.04, 0, 'LegendNANA'],
#  ['2020-02-05T00:00', 1.1, -5.6, 61.0, 0.0, 100.12, 0, 'LegendNANA'],
#  ['2020-02-05T01:00', 1.0, -5.1, 64.0, 0.0, 100.19, 0, 'LegendNANA'],
#  ['2020-02-05T02:00', 0.0, -7.9, 55.0, 0.0, 100.2, 0, 'LegendNANA'],
#  ['2020-02-05T03:00', -0.7, -8.7, 55.0, 0.0, 100.27, 0, 'LegendNANA'],
#  ['2020-02-05T04:00', -1.4, -8.5, 59.0, 0.0, 100.31, 0, 'LegendNANA'],
#  ['2020-02-05T05:00', -2.3, -9.7, 57.0, 0.0, 100.37, 0, 'LegendNANA'],
#  ['2020-02-05T06:00', -3.7, -11.8, 53.0, 0.0, 100.39, 0, 'LegendNANA'],
#  ['2020-02-05T07:00', -4.0, -11.8, 55.0, 0.0, 100.42, 0, 'LegendNANA'],
#  ['2020-02-05T08:00', -4.1, -11.5, 56.0, 0.0, 100.49, 0, 'LegendNANA'],
#  ['2020-02-05T09:00', -4.2, -10.7, 61.0, 0.0, 100.56, 0, 'LegendNANA'],
#  ['2020-02-05T10:00', -4.8, -11.5, 59.0, 0.0, 100.68, 0, 'LegendNANA'],
#  ['2020-02-05T11:00', -4.8, -11.3, 61.0, 0.0, 100.73, 0, 'LegendNANA'],
#  ['2020-02-05T12:00', -5.8, -12.0, 62.0, 0.0, 100.82, 0, 'LegendNANA'],
#  ['2020-02-05T13:00', -6.7, -12.7, 62.0, 0.0, 100.85, 0, 'LegendNANA'],
#  ['2020-02-05T14:00', -6.7, -13.9, 57.0, 0.0, 100.98, 0, 'LegendNANA'],
#  ['2020-02-05T15:00', -5.8, -13.0, 56.0, 0.0, 100.88, 0, 'LegendNANA'],
#  ['2020-02-05T16:00', -4.9, -14.9, 45.0, 0.0, 101.01, 0, 'LegendNANA'],
#  ['2020-02-05T17:00', -3.9, -17.5, 34.0, 0.0, 100.89, 0, 'LegendNANA'],
#  ['2020-02-05T18:00', -2.9, -13.5, 44.0, 0.0, 100.83, 0, 'LegendNANA'],
#  ['2020-02-05T19:00', -3.2, -14.9, 40.0, 0.3, 100.62, 0, 'LegendNANA'],
#  ['2020-02-05T20:00', -3.4, -11.9, 52.0, 0.0, 100.64, 0, 'LegendNANA'],
#  ['2020-02-05T21:00', -3.6, -12.1, 52.0, 0.0, 100.59, 0, 'LegendNANA'],
#  ['2020-02-05T22:00', -3.7, -12.7, 50.0, 0.0, 100.53, 0, 'LegendNANA'],
#  ['2020-02-05T23:00', -3.8, -12.2, 52.0, 0.0, 100.42, 0, 'LegendNANA'],
#  ['2020-02-06T00:00', -3.7, -12.5, 51.0, 0.0, 100.38, 0, 'LegendNANA'],
#  ['2020-02-06T01:00', -3.5, -12.2, 51.0, 0.0, 100.37, 0, 'LegendNANA'],
#  ['2020-02-06T02:00', -3.3, -11.4, 53.0, 0.0, 100.22, 0, 'LegendNANA'],
#  ['2020-02-06T03:00', -3.0, -11.3, 53.0, 0.0, 99.97, 0, 'LegendNANA'],
#  ['2020-02-06T04:00', -2.8, -10.8, 54.0, 0.0, 99.84, 0, 'LegendNANA'],
#  ['2020-02-06T05:00', -3.9, -9.0, 67.0, 0.0, 99.81, 0, 'LegendNANA'],
#  ['2020-02-06T06:00', -4.5, -6.4, 86.0, 0.7, 99.72, 0, 'LegendNANA'],
#  ['2020-02-06T07:00', -4.4, -6.5, 85.0, 0.5, 99.59, 0, 'LegendNANA'],
#  ['2020-02-06T08:00', -3.7, -5.5, 87.0, 0.2, 99.5, 0, 'LegendNANA'],
#  ['2020-02-06T09:00', -3.6, -5.5, 87.0, 0.3, 99.4, 0, 'LegendNANA'],
#  ['2020-02-06T10:00', -3.8, -5.8, 86.0, 0.2, 99.29, 0, 'LegendNANA'],
#  ['2020-02-06T11:00', -3.8, -6.0, 85.0, 0.6, 99.28, 0, 'LegendNANA'],
#  ['2020-02-06T12:00', -3.9, -6.2, 84.0, 0.3, 99.17, 0, 'LegendNANA'],
#  ['2020-02-06T13:00', -4.0, -5.7, 88.0, 0.5, 99.12, 0, 'LegendNANA'],
#  ['2020-02-06T14:00', -3.6, -5.7, 86.0, 0.2, 99.01, 0, 'LegendNANA'],
#  ['2020-02-06T15:00', -3.4, -5.8, 83.0, 0.2, 98.97, 0, 'LegendNANA'],
#  ['2020-02-06T16:00', -3.1, -5.8, 81.0, 0.0, 99.03, 0, 'LegendNANA'],
#  ['2020-02-06T17:00', -3.3, -5.7, 83.0, 0.6, 98.95, 0, 'LegendNANA'],
#  ['2020-02-06T18:00', -3.2, -6.8, 76.0, 0.0, 98.87, 0, 'LegendNANA'],
#  ['2020-02-06T19:00', -2.7, -7.1, 72.0, 0.0, 98.75, 0, 'LegendNANA'],
#  ['2020-02-06T20:00', -2.6, -7.6, 69.0, 0.0, 98.61, 0, 'LegendNANA'],
#  ['2020-02-06T21:00', -2.8, -7.8, 69.0, 0.0, 98.65, 0, 'LegendNANA'],
#  ['2020-02-06T22:00', -2.8, -7.5, 70.0, 0.0, 98.55, 0, 'LegendNANA'],
#  ['2020-02-06T23:00', -3.2, -7.8, 70.0, 0.0, 98.49, 0, 'LegendNANA'],
#  ['2020-02-07T00:00', -3.1, -7.3, 73.0, 0.2, 98.6, 0, 'LegendNANA'],
#  ['2020-02-07T01:00', -3.6, -6.4, 81.0, 0.0, 98.52, 0, 'LegendNANA'],
#  ['2020-02-07T02:00', -3.9, -5.9, 86.0, 0.6, 98.51, 0, 'LegendNANA'],
#  ['2020-02-07T03:00', -4.1, -5.6, 89.0, 1.5, 98.48, 0, 'LegendNANA'],
#  ['2020-02-07T04:00', -4.3, -5.9, 88.0, 1.0, 98.37, 0, 'LegendNANA'],
#  ['2020-02-07T05:00', -4.4, -6.3, 87.0, 0.5, 98.38, 0, 'LegendNANA'],
#  ['2020-02-07T06:00', -4.5, -6.6, 85.0, 0.2, 98.32, 0, 'LegendNANA'],
#  ['2020-02-07T07:00', -4.6, -6.7, 85.0, 0.2, 98.22, 0, 'LegendNANA'],
#  ['2020-02-07T08:00', -4.5, -7.1, 82.0, 0.3, 98.25, 0, 'LegendNANA'],
#  ['2020-02-07T09:00', -4.4, -7.3, 80.0, 0.0, 98.22, 0, 'LegendNANA'],
#  ['2020-02-07T10:00', -4.7, -7.4, 82.0, 0.2, 97.99, 0, 'LegendNANA'],
#  ['2020-02-07T11:00', -4.4, -7.7, 78.0, 0.0, 97.96, 0, 'LegendNANA'],
#  ['2020-02-07T12:00', -4.3, -8.0, 75.0, 0.0, 97.95, 0, 'LegendNANA'],
#  ['2020-02-07T13:00', -4.1, -7.9, 75.0, 0.0, 98.0, 0, 'LegendNANA'],
#  ['2020-02-07T14:00', -4.1, -7.8, 76.0, 0.0, 98.01, 0, 'LegendNANA'],
#  ['2020-02-07T15:00', -4.4, -7.0, 82.0, 0.2, 98.03, 0, 'LegendNANA'],
#  ['2020-02-07T16:00', -4.4, -7.3, 81.0, 0.3, 98.1, 0, 'LegendNANA'],
#  ['2020-02-07T17:00', -3.7, -8.8, 68.0, 0.2, 98.11, 0, 'LegendNANA'],
#  ['2020-02-07T18:00', -3.5, -9.3, 64.0, 0.0, 98.14, 0, 'LegendNANA'],
#  ['2020-02-07T19:00', -3.9, -10.0, 62.0, 0.0, 98.26, 0, 'LegendNANA'],
#  ['2020-02-07T20:00', -3.9, -10.0, 63.0, 0.0, 98.37, 0, 'LegendNANA'],
#  ['2020-02-07T21:00', -4.3, -10.8, 61.0, 0.0, 98.55, 0, 'LegendNANA'],
#  ['2020-02-07T22:00', -4.6, -11.7, 58.0, 0.0, 98.72, 0, 'LegendNANA'],
#  ['2020-02-07T23:00', -5.3, -12.2, 59.0, 0.0, 98.92, 0, 'LegendNANA'],
#  ['2020-02-08T00:00', -5.7, -13.0, 56.0, 0.0, 99.12, 0, 'LegendNANA'],
#  ['2020-02-08T01:00', -6.2, -12.8, 59.0, 0.0, 99.28, 0, 'LegendNANA'],
#  ['2020-02-08T02:00', -6.6, -12.6, 62.0, 0.0, 99.44, 0, 'LegendNANA'],
#  ['2020-02-08T03:00', -6.8, -12.5, 64.0, 0.0, 99.58, 0, 'LegendNANA'],
#  ['2020-02-08T04:00', -7.0, -12.9, 63.0, 0.0, 99.66, 0, 'LegendNANA'],
#  ['2020-02-08T05:00', -7.5, -12.9, 65.0, 0.0, 99.78, 0, 'LegendNANA'],
#  ['2020-02-08T06:00', -7.4, -12.4, 67.0, 0.0, 99.88, 0, 'LegendNANA'],
#  ['2020-02-08T07:00', -8.6, -14.6, 62.0, 0.0, 99.92, 0, 'LegendNANA'],
#  ['2020-02-08T08:00', -9.7, -16.9, 56.0, 0.0, 100.02, 0, 'LegendNANA'],
#  ['2020-02-08T09:00', -10.7, -17.7, 56.0, 0.0, 100.14, 0, 'LegendNANA'],
#  ['2020-02-08T10:00', -11.5, -18.1, 58.0, 0.0, 100.25, 0, 'LegendNANA'],
#  ['2020-02-08T11:00', -12.1, -18.3, 60.0, 0.0, 100.35, 0, 'LegendNANA'],
#  ['2020-02-08T12:00', -12.9, -19.0, 60.0, 0.0, 100.47, 0, 'LegendNANA'],
#  ['2020-02-08T13:00', -13.4, -19.6, 59.0, 0.0, 100.58, 0, 'LegendNANA'],
#  ['2020-02-08T14:00', -12.6, -19.4, 57.0, 0.0, 100.73, 0, 'LegendNANA'],
#  ['2020-02-08T15:00', -11.7, -19.0, 55.0, 0.0, 100.8, 0, 'LegendNANA'],
#  ['2020-02-08T16:00', -11.5, -19.2, 53.0, 0.0, 100.91, 0, 'LegendNANA'],
#  ['2020-02-08T17:00', -9.1, -18.2, 48.0, 0.0, 100.91, 0, 'LegendNANA'],
#  ['2020-02-08T18:00', -7.2, -18.2, 41.0, 0.0, 100.9, 0, 'LegendNANA'],
#  ['2020-02-08T19:00', -7.0, -16.1, 48.0, 1.1, 100.89, 0, 'LegendNANA'],
#  ['2020-02-08T20:00', -7.4, -15.0, 55.0, 0.0, 100.91, 0, 'LegendNANA'],
#  ['2020-02-08T21:00', -7.6, -14.7, 57.0, 0.0, 100.96, 0, 'LegendNANA'],
#  ['2020-02-08T22:00', -7.7, -14.6, 57.0, 0.0, 101.05, 0, 'LegendNANA'],
#  ['2020-02-08T23:00', -7.9, -14.8, 58.0, 0.0, 101.12, 0, 'LegendNANA'],
#  ['2020-02-09T00:00', -7.6, -13.7, 61.0, 0.0, 101.19, 0, 'LegendNANA'],
#  ['2020-02-09T01:00', -6.9, -12.2, 66.0, 0.0, 101.21, 0, 'LegendNANA'],
#  ['2020-02-09T02:00', -6.6, -11.5, 68.0, 0.0, 101.23, 0, 'LegendNANA'],
#  ['2020-02-09T03:00', -6.4, -11.0, 70.0, 0.0, 101.27, 0, 'LegendNANA'],
#  ['2020-02-09T04:00', -7.0, -11.5, 70.0, 0.0, 101.29, 0, 'LegendNANA'],
#  ['2020-02-09T05:00', -7.3, -12.1, 69.0, 0.0, 101.28, 0, 'LegendNANA'],
#  ['2020-02-09T06:00', -7.2, -12.1, 68.0, 0.0, 101.31, 0, 'LegendNANA'],
#  ['2020-02-09T07:00', -7.0, -11.7, 69.0, 0.0, 101.35, 0, 'LegendNANA'],
#  ['2020-02-09T08:00', -7.6, -12.2, 70.0, 0.0, 101.4, 0, 'LegendNANA'],
#  ['2020-02-09T09:00', -7.2, -11.6, 71.0, 0.0, 101.43, 0, 'LegendNANA'],
#  ['2020-02-09T10:00', -7.2, -11.1, 74.0, 0.0, 101.44, 0, 'LegendNANA'],
#  ['2020-02-09T11:00', -6.1, -9.0, 80.0, 0.0, 101.45, 0, 'LegendNANA'],
#  ['2020-02-09T12:00', -5.4, -7.7, 84.0, 0.0, 101.47, 0, 'LegendNANA'],
#  ['2020-02-09T13:00', -5.1, -7.4, 84.0, 0.0, 101.5, 0, 'LegendNANA'],
#  ['2020-02-09T14:00', -4.2, -7.1, 80.0, 0.0, 101.52, 0, 'LegendNANA'],
#  ['2020-02-09T15:00', -2.2, -5.4, 79.0, 0.0, 101.53, 0, 'LegendNANA'],
#  ['2020-02-09T16:00', -1.4, -5.3, 75.0, 0.0, 101.51, 0, 'LegendNANA'],
#  ['2020-02-09T17:00', -0.4, -4.8, 72.0, 0.2, 101.47, 0, 'LegendNANA'],
#  ['2020-02-09T18:00', -0.2, -4.6, 72.0, 0.0, 101.35, 0, 'LegendNANA'],
#  ['2020-02-09T19:00', -0.3, -3.8, 77.0, 0.0, 101.21, 0, 'LegendNANA'],
#  ['2020-02-09T20:00', -0.3, -3.4, 79.0, 0.0, 101.18, 0, 'LegendNANA'],
#  ['2020-02-09T21:00', 0.0, -2.8, 82.0, 0.0, 101.16, 0, 'LegendNANA'],
#  ['2020-02-09T22:00', 0.3, -2.4, 82.0, 0.0, 101.11, 0, 'LegendNANA'],
#  ['2020-02-09T23:00', 1.4, -2.2, 77.0, 0.0, 100.92, 0, 'LegendNANA'],
#  ['2020-02-10T00:00', 2.0, -2.4, 73.0, 0.0, 100.83, 0, 'LegendNANA'],
#  ['2020-02-10T01:00', 0.6, -0.9, 90.0, 0.6, 100.74, 0, 'LegendNANA'],
#  ['2020-02-10T02:00', 0.4, -0.7, 93.0, 1.2, 100.58, 0, 'LegendNANA'],
#  ['2020-02-10T03:00', 0.6, -0.4, 94.0, 0.8, 100.46, 0, 'LegendNANA'],
#  ['2020-02-10T04:00', 0.8, -0.2, 93.0, 0.8, 100.27, 0, 'LegendNANA'],
#  ['2020-02-10T05:00', 0.9, -0.2, 93.0, 1.1, 100.13, 0, 'LegendNANA'],
#  ['2020-02-10T06:00', 1.0, -0.1, 92.0, 1.1, 100.0, 0, 'LegendNANA'],
#  ['2020-02-10T07:00', 1.5, 0.5, 93.0, 0.8, 99.91, 0, 'LegendNANA'],
#  ['2020-02-10T08:00', 1.9, 0.8, 92.0, 0.2, 99.87, 0, 'LegendNANA'],
#  ['2020-02-10T09:00', 2.1, 0.9, 91.0, 0.0, 99.82, 0.0, 'LegendNANA'],
#  ['2020-02-10T10:00', 2.0, 0.5, 90.0, 0.0, 99.83, 0, 'LegendNANA'],
#  ['2020-02-10T11:00', 2.2, 0.7, 90.0, 0.0, 99.88, 0.0, 'LegendNANA'],
#  ['2020-02-10T12:00', 2.4, 0.6, 88.0, 0.0, 99.95, 0.0, 'LegendNANA'],
#  ['2020-02-10T13:00', 2.3, 0.4, 87.0, 0.0, 100.07, 0.0, 'LegendNANA'],
#  ['2020-02-10T14:00', 2.6, 0.2, 84.0, 0.0, 100.18, 0.0, 'LegendNANA'],
#  ['2020-02-10T15:00', 2.6, -0.7, 79.0, 0.0, 100.24, 0.0, 'LegendNANA'],
#  ['2020-02-10T16:00', 3.4, -2.9, 63.0, 0.0, 100.32, 1.0, 'LegendNANA'],
#  ['2020-02-10T17:00', 4.0, -3.2, 59.0, 0.0, 100.37, 1.0, 'LegendNANA'],
#  ['2020-02-10T18:00', 3.8, -2.7, 62.0, 0.3, 100.38, 1.0, 'LegendNANA'],
#  ['2020-02-10T19:00', 3.4, -3.0, 63.0, 0.0, 100.39, 1.0, 'LegendNANA'],
#  ['2020-02-10T20:00', 3.5, -3.4, 61.0, 0.0, 100.44, 1.0, 'LegendNANA'],
#  ['2020-02-10T21:00', 3.3, -3.5, 61.0, 0.0, 100.5, 0.0, 'LegendNANA'],
#  ['2020-02-10T22:00', 2.6, -3.9, 62.0, 0.0, 100.51, 0, 'LegendNANA'],
#  ['2020-02-10T23:00', 2.3, -3.4, 66.0, 0.0, 100.56, 0, 'LegendNANA'],
#  ['2020-02-11T00:00', 2.0, -3.9, 65.0, 0.0, 100.59, 0, 'LegendNANA'],
#  ['2020-02-11T01:00', 1.7, -3.9, 66.0, 0.0, 100.56, 0, 'LegendNANA'],
#  ['2020-02-11T02:00', 1.5, -4.1, 66.0, 0.0, 100.57, 0, 'LegendNANA'],
#  ['2020-02-11T03:00', 1.5, -4.4, 65.0, 0.0, 100.57, 0, 'LegendNANA'],
#  ['2020-02-11T04:00', 1.3, -4.4, 66.0, 0.0, 100.54, 0, 'LegendNANA'],
#  ['2020-02-11T05:00', 1.2, -4.1, 68.0, 0.0, 100.49, 0, 'LegendNANA'],
#  ['2020-02-11T06:00', 1.1, -4.1, 68.0, 0.0, 100.42, 0, 'LegendNANA'],
#  ['2020-02-11T07:00', 0.9, -4.3, 68.0, 0.0, 100.36, 0, 'LegendNANA'],
#  ['2020-02-11T08:00', 1.0, -4.0, 69.0, 0.0, 100.38, 0, 'LegendNANA'],
#  ['2020-02-11T09:00', 0.9, -4.0, 70.0, 0.0, 100.35, 0, 'LegendNANA'],
#  ['2020-02-11T10:00', 0.8, -3.8, 71.0, 0.0, 100.31, 0, 'LegendNANA'],
#  ['2020-02-11T11:00', 0.8, -3.4, 73.0, 0.0, 100.31, 0, 'LegendNANA'],
#  ['2020-02-11T12:00', 0.7, -3.7, 72.0, 0.0, 100.25, 0, 'LegendNANA'],
#  ['2020-02-11T13:00', 0.9, -4.2, 69.0, 0.0, 100.27, 0, 'LegendNANA'],
#  ['2020-02-11T14:00', 0.6, -5.5, 64.0, 0.0, 100.21, 0, 'LegendNANA'],
#  ['2020-02-11T15:00', 0.9, -6.0, 60.0, 0.0, 100.16, 0, 'LegendNANA'],
#  ...]

# %% [markdown]
# ##### Forecast weather via available data
